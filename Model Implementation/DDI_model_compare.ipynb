# %%
import csv
import math
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.optimize as opt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, KBinsDiscretizer, RobustScaler, PolynomialFeatures, StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score
from sklearn.pipeline import Pipeline
from sklearn.decomposition import IncrementalPCA
from tabulate import tabulate
import tensorflow as tf
import deepchem as dc
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Descriptors
from tensorflow import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.loader import DataLoader
from torch_geometric.data import Data
import pyarrow as pa
import pyarrow.parquet as pq
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# WARNING:tensorflow:From C:\Users\warre\anaconda3\Lib\site-packages\tensorflow\python\util\deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead

# %% [markdown]
# ## Assorted Functions

# %%
#Basic dimensionality reduction down to a selected number of components
#have X include cols to be able to rejoin with datasets if desired
def Dim_red(X, feature_num, batch_size, col_name):
	ipca = IncrementalPCA(n_components=feature_num)

	for i in range(0, X.shape[0], batch_size):
	    X_batch = X[i:i + batch_size]
	    ipca.partial_fit(X_batch)

	X_transformed = pd.DataFrame(ipca.transform(X))
	X_transformed['cols'] = X[col_name]

	#prove that X's shape has changed
	#print("Original shape:", X.shape)
	#print("Transformed shape:", X_transformed.shape)

	return(X_transformed)

#quick function to turn a list of size 1 lists of strings into a list of strings, for later use
def delist(list_of_lists):
    list_of_strings = []
    for inner_list in list_of_lists:
        string = inner_list[0]
        list_of_strings.append(string)
    return list_of_strings

#a function to calculate layer nodes if using many
def calc_layers(X_size, Y_size):
    layers = [X_size+1]
    layer = 2
    while layer <= X_size:
        layer = int(layer * 2)
    layers.append(layer)
    if X_size > Y_size:
        while layer / 2 > Y_size and layer > 2:
            layer = layer / 2
            layers.append(int(layer))
    layers.append(Y_size)
    return layers

# %% [markdown]
# ## Feed-Forward Deep Neural Network model implementation

# %%
#basic/rough neural network implementation functions

#a function to perform feed-forward deep neural network analysis
def DNN(X, Y, Epochs, batchsize, layernum=1, verbose=False):

    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=27, stratify=Y)
    
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    #define layers and nodes in each layer
    input = len(X.columns)
    output = Y.shape[1]
    if layernum=='many':
        layers = calc_layers(input,output)
    elif type(layernum)==int:
        layers = [input]
        for i in range(layernum, 1, -1):
            layer = int(round((i * (input + output) / (layernum+1)), 0))
            if layer > output:
                layers.append(layer)
        layers.append(output)
    else:
        print(f"incorrect layernum {layernum}")
        return None

    model = keras.models.Sequential()

    model.add(Dense(layers[0], activation='relu'))
    model.add(keras.layers.Dropout(0.2))

    for layer_size in layers[1:-1]:
        model.add(Dense(layer_size, activation='relu'))
        model.add(keras.layers.Dropout(0.2))
        
    model.add(Dense(layers[-1], activation='softmax'))
    
    model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy','AUC','precision','recall'])
    
    model.fit(X_train, y_train, epochs=Epochs, batch_size=batchsize, validation_split=0.1, verbose=verbose)
    
    loss, accuracy, AUC, precision, recall = model.evaluate(X_test, y_test, verbose=0)
    if verbose:
        print(f"Test Loss: {loss}")
        print(f"Test Accuracy: {accuracy}")
        print(f"Test AUC: {AUC}")
        print(f"Test Precision: {precision}")
        print(f"Test Recall: {recall}")
    return model, accuracy

# %% [markdown]
# ## Adding In GNN

# %%
#Creating GNN Model
#credit Beth Farr
class GNN(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(GNN, self).__init__()
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, output_dim)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1)

#Using PyTorch Geometric Graph Format
def create_graph_features(features, labels):
    num_nodes = len(features)

    # creating the nodes
    edge_index = torch.tensor(
        np.array([[i, i] for i in range(num_nodes)]).T, dtype=torch.long
    )

    graphs = []
    for i in range(len(features)):
        x = torch.tensor(features[i], dtype=torch.float).unsqueeze(0)
        y = torch.tensor([labels[i]], dtype=torch.long)
        graph = Data(x=x, edge_index=edge_index, y=y)
        graphs.append(graph)
    return graphs

#Training the GNN Model
def GNN_train(model, train_loader, optimizer, criterion):
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(torch.device("cpu"))  # Ensure correct device
        optimizer.zero_grad()
        out = model(data)
        loss = criterion(out.squeeze(1), data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(train_loader)

#Evaluating the Model
def GNN_test(model, loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data in loader:
            data = data.to(torch.device("cpu"))  # Ensure correct device
            out = model(data)
            pred = out.argmax(dim=1)
            correct += (pred == data.y).sum().item()
            total += data.y.cpu().size(0)
    acc = correct / total
    return acc

def perform_GNN(X, Y, epochs, batchsize, verbose=False):

    #Train-Test Split
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)
                                                    
    train_graphs = create_graph_features(X_train, y_train)
    test_graphs = create_graph_features(X_test, y_test)

    # Creating data loaders
    train_loader = DataLoader(train_graphs, batch_size=batchsize, shuffle=True)
    test_loader = DataLoader(test_graphs, batch_size=batchsize, shuffle=False)

    #Initialising the Model
    input_dim = X.shape[1]
    output_dim = len(np.unique(Y))
    hidden_dim = int(round((input_dim + output_dim)/2,0))
    
    model = GNN(input_dim, hidden_dim, output_dim)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    criterion = torch.nn.CrossEntropyLoss()

    #Running Training
    accuracy = 0
    for epoch in range(epochs):
        loss = GNN_train(model, train_loader, optimizer, criterion)
        acc = GNN_test(model, test_loader)
        if verbose:
            print(f"Epoch {epoch+1}: Loss={loss:.4f}, Test Accuracy={acc:.4f}")
        if acc > accuracy:
            accuracy = acc

    #Saving the model for future use
    torch.save(model.state_dict(), "gnn_model.pth")
    return model, accuracy

# %% [markdown]
# ## Optimizing Hyperparameters

# %%
#function to optimize hyperparameters
def opt_hps(func, X, Y, epochs, batchsizes, show_progress=False):
    best_epochs = 0
    best_batchsize = 0
    best_acc = 0 
    grid = pd.DataFrame(columns=epochs, index=batchsizes)
    iter = 0
    max_rep = len(epochs) * len(batchsizes)

    for e in range(0,len(epochs)):
        for b in range(0,len(batchsizes)):
            if show_progress:
                iter += 1
                pct = int(round(iter / max_rep * 100,0))
                print(f"Performing {epochs[e]} epochs on batches of {batchsizes[b]}, {pct} percent complete")
            model, acc = func(X, Y, epochs[e], batchsizes[b])

            if show_progress:
                print(f"assigning {acc} to {grid.iloc[b, e]} ")
            grid.iloc[b, e] = acc
            
            if show_progress:
                print(grid)

            if acc > best_acc:
                best_epochs = epochs[e]
                best_batchsize = batchsizes[b]
                best_acc = acc

    print(f"Optimal hyperparams: {best_epochs} epochs, {best_batchsize} batchsize. Accuracy: {best_acc}")
    return grid

# %% [markdown]
# ## Initialization
# from *DDI_prep.py* processing

# %%
#initialize dataframes
table = pq.read_table('..\\Data Files\\DDI_eq_feat.parquet')
df_eq_feat = table.to_pandas()

table2 = pq.read_table('..\\Data Files\\DDI_red_feat.parquet')
df_red_feat = table2.to_pandas()

# %%
label_encoder = LabelEncoder()
graph_eq_feat_y = label_encoder.fit_transform(df_eq_feat['y'])
graph_red_feat_y = label_encoder.fit_transform(df_red_feat['y'])
eq_feat_y = to_categorical(df_eq_feat['y'])
red_feat_y = to_categorical(df_red_feat['y'])

eq_feat_x = df_eq_feat.iloc[:,2:]
red_feat_x = df_red_feat.iloc[:,2:]

# %% [markdown]
# ## Hyperparameter settings

# %%
dnn_epochs = [7,8,9,10,11]
dnn_batchsizes = [150, 200, 250, 300, 350, 400]

gnn_epochs = [5,6,7,8,9]
gnn_batchsizes = [100, 125,150, 175, 200, 225]

# %% [markdown]
# ## Deep (Feed-forward) Neural Network

# %%
#equalized with equal number of values in each of the top 20 categories
dnn_grid_eq = opt_hps(DNN, eq_feat_x, eq_feat_y, dnn_epochs, dnn_batchsizes, show_progress=True)

dnn_grid_eq
# Out:
# Performing 7 epochs on batches of 150, 3 percent complete
# assigning 0.8554999828338623 to nan
#          7    8    9    10   11
# 150  0.8555  NaN  NaN  NaN  NaN
# 200     NaN  NaN  NaN  NaN  NaN
# 250     NaN  NaN  NaN  NaN  NaN
# 300     NaN  NaN  NaN  NaN  NaN
# 350     NaN  NaN  NaN  NaN  NaN
# 400     NaN  NaN  NaN  NaN  NaN
# Performing 7 epochs on batches of 200, 7 percent complete
# assigning 0.8579999804496765 to nan
#          7    8    9    10   11
# 150  0.8555  NaN  NaN  NaN  NaN
# 200   0.858  NaN  NaN  NaN  NaN
# 250     NaN  NaN  NaN  NaN  NaN
# 300     NaN  NaN  NaN  NaN  NaN
# 350     NaN  NaN  NaN  NaN  NaN
# 400     NaN  NaN  NaN  NaN  NaN
# Performing 7 epochs on batches of 250, 10 percent complete
# assigning 0.8585000038146973 to nan
#          7    8    9    10   11
# 150  0.8555  NaN  NaN  NaN  NaN
# 200   0.858  NaN  NaN  NaN  NaN
# 250  0.8585  NaN  NaN  NaN  NaN
# 300     NaN  NaN  NaN  NaN  NaN
# 350     NaN  NaN  NaN  NaN  NaN
# 400     NaN  NaN  NaN  NaN  NaN
# Performing 7 epochs on batches of 300, 13 percent complete
# assigning 0.8514999747276306 to nan
#          7    8    9    10   11
# 150  0.8555  NaN  NaN  NaN  NaN
# 200   0.858  NaN  NaN  NaN  NaN
# 250  0.8585  NaN  NaN  NaN  NaN
# 300  0.8515  NaN  NaN  NaN  NaN
# 350     NaN  NaN  NaN  NaN  NaN
# 400     NaN  NaN  NaN  NaN  NaN
# Performing 7 epochs on batches of 350, 17 percent complete
# assigning 0.859499990940094 to nan
#          7    8    9    10   11
# 150  0.8555  NaN  NaN  NaN  NaN
# 200   0.858  NaN  NaN  NaN  NaN
# 250  0.8585  NaN  NaN  NaN  NaN
# 300  0.8515  NaN  NaN  NaN  NaN
# 350  0.8595  NaN  NaN  NaN  NaN
# 400     NaN  NaN  NaN  NaN  NaN
# Performing 7 epochs on batches of 400, 20 percent complete
# assigning 0.8585000038146973 to nan
#          7    8    9    10   11
# 150  0.8555  NaN  NaN  NaN  NaN
# 200   0.858  NaN  NaN  NaN  NaN
# 250  0.8585  NaN  NaN  NaN  NaN
# 300  0.8515  NaN  NaN  NaN  NaN
# 350  0.8595  NaN  NaN  NaN  NaN
# 400  0.8585  NaN  NaN  NaN  NaN
# Performing 8 epochs on batches of 150, 23 percent complete
# assigning 0.8495000004768372 to nan
#          7       8    9    10   11
# 150  0.8555  0.8495  NaN  NaN  NaN
# 200   0.858     NaN  NaN  NaN  NaN
# 250  0.8585     NaN  NaN  NaN  NaN
# 300  0.8515     NaN  NaN  NaN  NaN
# 350  0.8595     NaN  NaN  NaN  NaN
# 400  0.8585     NaN  NaN  NaN  NaN
# Performing 8 epochs on batches of 200, 27 percent complete
# assigning 0.8535000085830688 to nan
#          7       8    9    10   11
# 150  0.8555  0.8495  NaN  NaN  NaN
# 200   0.858  0.8535  NaN  NaN  NaN
# 250  0.8585     NaN  NaN  NaN  NaN
# 300  0.8515     NaN  NaN  NaN  NaN
# 350  0.8595     NaN  NaN  NaN  NaN
# 400  0.8585     NaN  NaN  NaN  NaN
# Performing 8 epochs on batches of 250, 30 percent complete
# assigning 0.859000027179718 to nan
#          7       8    9    10   11
# 150  0.8555  0.8495  NaN  NaN  NaN
# 200   0.858  0.8535  NaN  NaN  NaN
# 250  0.8585   0.859  NaN  NaN  NaN
# 300  0.8515     NaN  NaN  NaN  NaN
# 350  0.8595     NaN  NaN  NaN  NaN
# 400  0.8585     NaN  NaN  NaN  NaN
# Performing 8 epochs on batches of 300, 33 percent complete
# assigning 0.8539999723434448 to nan
#          7       8    9    10   11
# 150  0.8555  0.8495  NaN  NaN  NaN
# 200   0.858  0.8535  NaN  NaN  NaN
# 250  0.8585   0.859  NaN  NaN  NaN
# 300  0.8515   0.854  NaN  NaN  NaN
# 350  0.8595     NaN  NaN  NaN  NaN
# 400  0.8585     NaN  NaN  NaN  NaN
# Performing 8 epochs on batches of 350, 37 percent complete
# assigning 0.8560000061988831 to nan
#          7       8    9    10   11
# 150  0.8555  0.8495  NaN  NaN  NaN
# 200   0.858  0.8535  NaN  NaN  NaN
# 250  0.8585   0.859  NaN  NaN  NaN
# 300  0.8515   0.854  NaN  NaN  NaN
# 350  0.8595   0.856  NaN  NaN  NaN
# 400  0.8585     NaN  NaN  NaN  NaN
# Performing 8 epochs on batches of 400, 40 percent complete
# assigning 0.8629999756813049 to nan
#          7       8    9    10   11
# 150  0.8555  0.8495  NaN  NaN  NaN
# 200   0.858  0.8535  NaN  NaN  NaN
# 250  0.8585   0.859  NaN  NaN  NaN
# 300  0.8515   0.854  NaN  NaN  NaN
# 350  0.8595   0.856  NaN  NaN  NaN
# 400  0.8585   0.863  NaN  NaN  NaN
# Performing 9 epochs on batches of 150, 43 percent complete
# assigning 0.8514999747276306 to nan
#          7       8       9    10   11
# 150  0.8555  0.8495  0.8515  NaN  NaN
# 200   0.858  0.8535     NaN  NaN  NaN
# 250  0.8585   0.859     NaN  NaN  NaN
# 300  0.8515   0.854     NaN  NaN  NaN
# 350  0.8595   0.856     NaN  NaN  NaN
# 400  0.8585   0.863     NaN  NaN  NaN
# Performing 9 epochs on batches of 200, 47 percent complete
# assigning 0.8575000166893005 to nan
#          7       8       9    10   11
# 150  0.8555  0.8495  0.8515  NaN  NaN
# 200   0.858  0.8535  0.8575  NaN  NaN
# 250  0.8585   0.859     NaN  NaN  NaN
# 300  0.8515   0.854     NaN  NaN  NaN
# 350  0.8595   0.856     NaN  NaN  NaN
# 400  0.8585   0.863     NaN  NaN  NaN
# Performing 9 epochs on batches of 250, 50 percent complete
# assigning 0.8640000224113464 to nan
#          7       8       9    10   11
# 150  0.8555  0.8495  0.8515  NaN  NaN
# 200   0.858  0.8535  0.8575  NaN  NaN
# 250  0.8585   0.859   0.864  NaN  NaN
# 300  0.8515   0.854     NaN  NaN  NaN
# 350  0.8595   0.856     NaN  NaN  NaN
# 400  0.8585   0.863     NaN  NaN  NaN
# Performing 9 epochs on batches of 300, 53 percent complete
# assigning 0.8579999804496765 to nan
#          7       8       9    10   11
# 150  0.8555  0.8495  0.8515  NaN  NaN
# 200   0.858  0.8535  0.8575  NaN  NaN
# 250  0.8585   0.859   0.864  NaN  NaN
# 300  0.8515   0.854   0.858  NaN  NaN
# 350  0.8595   0.856     NaN  NaN  NaN
# 400  0.8585   0.863     NaN  NaN  NaN
# Performing 9 epochs on batches of 350, 57 percent complete
# assigning 0.8634999990463257 to nan
#          7       8       9    10   11
# 150  0.8555  0.8495  0.8515  NaN  NaN
# 200   0.858  0.8535  0.8575  NaN  NaN
# 250  0.8585   0.859   0.864  NaN  NaN
# 300  0.8515   0.854   0.858  NaN  NaN
# 350  0.8595   0.856  0.8635  NaN  NaN
# 400  0.8585   0.863     NaN  NaN  NaN
# Performing 9 epochs on batches of 400, 60 percent complete
# assigning 0.8550000190734863 to nan
#          7       8       9    10   11
# 150  0.8555  0.8495  0.8515  NaN  NaN
# 200   0.858  0.8535  0.8575  NaN  NaN
# 250  0.8585   0.859   0.864  NaN  NaN
# 300  0.8515   0.854   0.858  NaN  NaN
# 350  0.8595   0.856  0.8635  NaN  NaN
# 400  0.8585   0.863   0.855  NaN  NaN
# Performing 10 epochs on batches of 150, 63 percent complete
# assigning 0.8510000109672546 to nan
#          7       8       9      10   11
# 150  0.8555  0.8495  0.8515  0.851  NaN
# 200   0.858  0.8535  0.8575    NaN  NaN
# 250  0.8585   0.859   0.864    NaN  NaN
# 300  0.8515   0.854   0.858    NaN  NaN
# 350  0.8595   0.856  0.8635    NaN  NaN
# 400  0.8585   0.863   0.855    NaN  NaN
# Performing 10 epochs on batches of 200, 67 percent complete
# assigning 0.8575000166893005 to nan
#          7       8       9       10   11
# 150  0.8555  0.8495  0.8515   0.851  NaN
# 200   0.858  0.8535  0.8575  0.8575  NaN
# 250  0.8585   0.859   0.864     NaN  NaN
# 300  0.8515   0.854   0.858     NaN  NaN
# 350  0.8595   0.856  0.8635     NaN  NaN
# 400  0.8585   0.863   0.855     NaN  NaN
# Performing 10 epochs on batches of 250, 70 percent complete
# assigning 0.8579999804496765 to nan
#          7       8       9       10   11
# 150  0.8555  0.8495  0.8515   0.851  NaN
# 200   0.858  0.8535  0.8575  0.8575  NaN
# 250  0.8585   0.859   0.864   0.858  NaN
# 300  0.8515   0.854   0.858     NaN  NaN
# 350  0.8595   0.856  0.8635     NaN  NaN
# 400  0.8585   0.863   0.855     NaN  NaN
# Performing 10 epochs on batches of 300, 73 percent complete
# assigning 0.8565000295639038 to nan
#          7       8       9       10   11
# 150  0.8555  0.8495  0.8515   0.851  NaN
# 200   0.858  0.8535  0.8575  0.8575  NaN
# 250  0.8585   0.859   0.864   0.858  NaN
# 300  0.8515   0.854   0.858  0.8565  NaN
# 350  0.8595   0.856  0.8635     NaN  NaN
# 400  0.8585   0.863   0.855     NaN  NaN
# Performing 10 epochs on batches of 350, 77 percent complete
# assigning 0.8554999828338623 to nan
#          7       8       9       10   11
# 150  0.8555  0.8495  0.8515   0.851  NaN
# 200   0.858  0.8535  0.8575  0.8575  NaN
# 250  0.8585   0.859   0.864   0.858  NaN
# 300  0.8515   0.854   0.858  0.8565  NaN
# 350  0.8595   0.856  0.8635  0.8555  NaN
# 400  0.8585   0.863   0.855     NaN  NaN
# Performing 10 epochs on batches of 400, 80 percent complete
# assigning 0.8610000014305115 to nan
#          7       8       9       10   11
# 150  0.8555  0.8495  0.8515   0.851  NaN
# 200   0.858  0.8535  0.8575  0.8575  NaN
# 250  0.8585   0.859   0.864   0.858  NaN
# 300  0.8515   0.854   0.858  0.8565  NaN
# 350  0.8595   0.856  0.8635  0.8555  NaN
# 400  0.8585   0.863   0.855   0.861  NaN
# Performing 11 epochs on batches of 150, 83 percent complete
# assigning 0.8445000052452087 to nan
#          7       8       9       10      11
# 150  0.8555  0.8495  0.8515   0.851  0.8445
# 200   0.858  0.8535  0.8575  0.8575     NaN
# 250  0.8585   0.859   0.864   0.858     NaN
# 300  0.8515   0.854   0.858  0.8565     NaN
# 350  0.8595   0.856  0.8635  0.8555     NaN
# 400  0.8585   0.863   0.855   0.861     NaN
# Performing 11 epochs on batches of 200, 87 percent complete
# assigning 0.8539999723434448 to nan
#          7       8       9       10      11
# 150  0.8555  0.8495  0.8515   0.851  0.8445
# 200   0.858  0.8535  0.8575  0.8575   0.854
# 250  0.8585   0.859   0.864   0.858     NaN
# 300  0.8515   0.854   0.858  0.8565     NaN
# 350  0.8595   0.856  0.8635  0.8555     NaN
# 400  0.8585   0.863   0.855   0.861     NaN
# Performing 11 epochs on batches of 250, 90 percent complete
# assigning 0.8575000166893005 to nan
#          7       8       9       10      11
# 150  0.8555  0.8495  0.8515   0.851  0.8445
# 200   0.858  0.8535  0.8575  0.8575   0.854
# 250  0.8585   0.859   0.864   0.858  0.8575
# 300  0.8515   0.854   0.858  0.8565     NaN
# 350  0.8595   0.856  0.8635  0.8555     NaN
# 400  0.8585   0.863   0.855   0.861     NaN
# Performing 11 epochs on batches of 300, 93 percent complete
# assigning 0.8650000095367432 to nan
#          7       8       9       10      11
# 150  0.8555  0.8495  0.8515   0.851  0.8445
# 200   0.858  0.8535  0.8575  0.8575   0.854
# 250  0.8585   0.859   0.864   0.858  0.8575
# 300  0.8515   0.854   0.858  0.8565   0.865
# 350  0.8595   0.856  0.8635  0.8555     NaN
# 400  0.8585   0.863   0.855   0.861     NaN
# Performing 11 epochs on batches of 350, 97 percent complete
# assigning 0.8585000038146973 to nan
#          7       8       9       10      11
# 150  0.8555  0.8495  0.8515   0.851  0.8445
# 200   0.858  0.8535  0.8575  0.8575   0.854
# 250  0.8585   0.859   0.864   0.858  0.8575
# 300  0.8515   0.854   0.858  0.8565   0.865
# 350  0.8595   0.856  0.8635  0.8555  0.8585
# 400  0.8585   0.863   0.855   0.861     NaN
# Performing 11 epochs on batches of 400, 100 percent complete
# assigning 0.8619999885559082 to nan
#          7       8       9       10      11
# 150  0.8555  0.8495  0.8515   0.851  0.8445
# 200   0.858  0.8535  0.8575  0.8575   0.854
# 250  0.8585   0.859   0.864   0.858  0.8575
# 300  0.8515   0.854   0.858  0.8565   0.865
# 350  0.8595   0.856  0.8635  0.8555  0.8585
# 400  0.8585   0.863   0.855   0.861   0.862
# Optimal hyperparams: 11 epochs, 300 batchsize. Accuracy: 0.8650000095367432
#          7       8       9       10      11
# 150  0.8555  0.8495  0.8515   0.851  0.8445
# 200   0.858  0.8535  0.8575  0.8575   0.854
# 250  0.8585   0.859   0.864   0.858  0.8575
# 300  0.8515   0.854   0.858  0.8565   0.865
# 350  0.8595   0.856  0.8635  0.8555  0.8585
# 400  0.8585   0.863   0.855   0.861   0.862

# %%
#just reduced to top 20 categories
dnn_grid_red = opt_hps(DNN, red_feat_x, red_feat_y, dnn_epochs, dnn_batchsizes, show_progress=True)

dnn_grid_red

# %% [markdown]
# ## Graph Neural Network
# (performance on same features)

# %%
#equalized
gnn_grid_eq = opt_hps(perform_GNN, eq_feat_x.values, graph_eq_feat_y, gnn_epochs, gnn_batchsizes, show_progress=True)

gnn_grid_eq
# Out:
# Performing 5 epochs on batches of 100, 3 percent complete
# assigning 0.7515 to nan
#           5    6    7    8    9
# 100  0.7515  NaN  NaN  NaN  NaN
# 125     NaN  NaN  NaN  NaN  NaN
# 150     NaN  NaN  NaN  NaN  NaN
# 175     NaN  NaN  NaN  NaN  NaN
# 200     NaN  NaN  NaN  NaN  NaN
# 225     NaN  NaN  NaN  NaN  NaN
# Performing 5 epochs on batches of 125, 7 percent complete
# assigning 0.7055 to nan
#           5    6    7    8    9
# 100  0.7515  NaN  NaN  NaN  NaN
# 125  0.7055  NaN  NaN  NaN  NaN
# 150     NaN  NaN  NaN  NaN  NaN
# 175     NaN  NaN  NaN  NaN  NaN
# 200     NaN  NaN  NaN  NaN  NaN
# 225     NaN  NaN  NaN  NaN  NaN
# Performing 5 epochs on batches of 150, 10 percent complete
# assigning 0.8175 to nan
#           5    6    7    8    9
# 100  0.7515  NaN  NaN  NaN  NaN
# 125  0.7055  NaN  NaN  NaN  NaN
# 150  0.8175  NaN  NaN  NaN  NaN
# 175     NaN  NaN  NaN  NaN  NaN
# 200     NaN  NaN  NaN  NaN  NaN
# 225     NaN  NaN  NaN  NaN  NaN
# Performing 5 epochs on batches of 175, 13 percent complete
# assigning 0.8045 to nan
#           5    6    7    8    9
# 100  0.7515  NaN  NaN  NaN  NaN
# 125  0.7055  NaN  NaN  NaN  NaN
# 150  0.8175  NaN  NaN  NaN  NaN
# 175  0.8045  NaN  NaN  NaN  NaN
# 200     NaN  NaN  NaN  NaN  NaN
# 225     NaN  NaN  NaN  NaN  NaN
# Performing 5 epochs on batches of 200, 17 percent complete
# assigning 0.833 to nan
#           5    6    7    8    9
# 100  0.7515  NaN  NaN  NaN  NaN
# 125  0.7055  NaN  NaN  NaN  NaN
# 150  0.8175  NaN  NaN  NaN  NaN
# 175  0.8045  NaN  NaN  NaN  NaN
# 200   0.833  NaN  NaN  NaN  NaN
# 225     NaN  NaN  NaN  NaN  NaN
# Performing 5 epochs on batches of 225, 20 percent complete
# assigning 0.7495 to nan
#           5    6    7    8    9
# 100  0.7515  NaN  NaN  NaN  NaN
# 125  0.7055  NaN  NaN  NaN  NaN
# 150  0.8175  NaN  NaN  NaN  NaN
# 175  0.8045  NaN  NaN  NaN  NaN
# 200   0.833  NaN  NaN  NaN  NaN
# 225  0.7495  NaN  NaN  NaN  NaN
# Performing 6 epochs on batches of 100, 23 percent complete
# assigning 0.808 to nan
#           5      6    7    8    9
# 100  0.7515  0.808  NaN  NaN  NaN
# 125  0.7055    NaN  NaN  NaN  NaN
# 150  0.8175    NaN  NaN  NaN  NaN
# 175  0.8045    NaN  NaN  NaN  NaN
# 200   0.833    NaN  NaN  NaN  NaN
# 225  0.7495    NaN  NaN  NaN  NaN
# Performing 6 epochs on batches of 125, 27 percent complete
# assigning 0.829 to nan
#           5      6    7    8    9
# 100  0.7515  0.808  NaN  NaN  NaN
# 125  0.7055  0.829  NaN  NaN  NaN
# 150  0.8175    NaN  NaN  NaN  NaN
# 175  0.8045    NaN  NaN  NaN  NaN
# 200   0.833    NaN  NaN  NaN  NaN
# 225  0.7495    NaN  NaN  NaN  NaN
# Performing 6 epochs on batches of 150, 30 percent complete
# assigning 0.7825 to nan
#           5       6    7    8    9
# 100  0.7515   0.808  NaN  NaN  NaN
# 125  0.7055   0.829  NaN  NaN  NaN
# 150  0.8175  0.7825  NaN  NaN  NaN
# 175  0.8045     NaN  NaN  NaN  NaN
# 200   0.833     NaN  NaN  NaN  NaN
# 225  0.7495     NaN  NaN  NaN  NaN
# Performing 6 epochs on batches of 175, 33 percent complete
# assigning 0.7955 to nan
#           5       6    7    8    9
# 100  0.7515   0.808  NaN  NaN  NaN
# 125  0.7055   0.829  NaN  NaN  NaN
# 150  0.8175  0.7825  NaN  NaN  NaN
# 175  0.8045  0.7955  NaN  NaN  NaN
# 200   0.833     NaN  NaN  NaN  NaN
# 225  0.7495     NaN  NaN  NaN  NaN
# Performing 6 epochs on batches of 200, 37 percent complete
# assigning 0.775 to nan
#           5       6    7    8    9
# 100  0.7515   0.808  NaN  NaN  NaN
# 125  0.7055   0.829  NaN  NaN  NaN
# 150  0.8175  0.7825  NaN  NaN  NaN
# 175  0.8045  0.7955  NaN  NaN  NaN
# 200   0.833   0.775  NaN  NaN  NaN
# 225  0.7495     NaN  NaN  NaN  NaN
# Performing 6 epochs on batches of 225, 40 percent complete
# assigning 0.831 to nan
#           5       6    7    8    9
# 100  0.7515   0.808  NaN  NaN  NaN
# 125  0.7055   0.829  NaN  NaN  NaN
# 150  0.8175  0.7825  NaN  NaN  NaN
# 175  0.8045  0.7955  NaN  NaN  NaN
# 200   0.833   0.775  NaN  NaN  NaN
# 225  0.7495   0.831  NaN  NaN  NaN
# Performing 7 epochs on batches of 100, 43 percent complete
# assigning 0.7925 to nan
#           5       6       7    8    9
# 100  0.7515   0.808  0.7925  NaN  NaN
# 125  0.7055   0.829     NaN  NaN  NaN
# 150  0.8175  0.7825     NaN  NaN  NaN
# 175  0.8045  0.7955     NaN  NaN  NaN
# 200   0.833   0.775     NaN  NaN  NaN
# 225  0.7495   0.831     NaN  NaN  NaN
# Performing 7 epochs on batches of 125, 47 percent complete
# assigning 0.7795 to nan
#           5       6       7    8    9
# 100  0.7515   0.808  0.7925  NaN  NaN
# 125  0.7055   0.829  0.7795  NaN  NaN
# 150  0.8175  0.7825     NaN  NaN  NaN
# 175  0.8045  0.7955     NaN  NaN  NaN
# 200   0.833   0.775     NaN  NaN  NaN
# 225  0.7495   0.831     NaN  NaN  NaN
# Performing 7 epochs on batches of 150, 50 percent complete
# assigning 0.8265 to nan
#           5       6       7    8    9
# 100  0.7515   0.808  0.7925  NaN  NaN
# 125  0.7055   0.829  0.7795  NaN  NaN
# 150  0.8175  0.7825  0.8265  NaN  NaN
# 175  0.8045  0.7955     NaN  NaN  NaN
# 200   0.833   0.775     NaN  NaN  NaN
# 225  0.7495   0.831     NaN  NaN  NaN
# Performing 7 epochs on batches of 175, 53 percent complete
# assigning 0.779 to nan
#           5       6       7    8    9
# 100  0.7515   0.808  0.7925  NaN  NaN
# 125  0.7055   0.829  0.7795  NaN  NaN
# 150  0.8175  0.7825  0.8265  NaN  NaN
# 175  0.8045  0.7955   0.779  NaN  NaN
# 200   0.833   0.775     NaN  NaN  NaN
# 225  0.7495   0.831     NaN  NaN  NaN
# Performing 7 epochs on batches of 200, 57 percent complete
# assigning 0.841 to nan
#           5       6       7    8    9
# 100  0.7515   0.808  0.7925  NaN  NaN
# 125  0.7055   0.829  0.7795  NaN  NaN
# 150  0.8175  0.7825  0.8265  NaN  NaN
# 175  0.8045  0.7955   0.779  NaN  NaN
# 200   0.833   0.775   0.841  NaN  NaN
# 225  0.7495   0.831     NaN  NaN  NaN
# Performing 7 epochs on batches of 225, 60 percent complete
# assigning 0.8095 to nan
#           5       6       7    8    9
# 100  0.7515   0.808  0.7925  NaN  NaN
# 125  0.7055   0.829  0.7795  NaN  NaN
# 150  0.8175  0.7825  0.8265  NaN  NaN
# 175  0.8045  0.7955   0.779  NaN  NaN
# 200   0.833   0.775   0.841  NaN  NaN
# 225  0.7495   0.831  0.8095  NaN  NaN
# Performing 8 epochs on batches of 100, 63 percent complete
# assigning 0.8 to nan
#           5       6       7    8    9
# 100  0.7515   0.808  0.7925  0.8  NaN
# 125  0.7055   0.829  0.7795  NaN  NaN
# 150  0.8175  0.7825  0.8265  NaN  NaN
# 175  0.8045  0.7955   0.779  NaN  NaN
# 200   0.833   0.775   0.841  NaN  NaN
# 225  0.7495   0.831  0.8095  NaN  NaN
# Performing 8 epochs on batches of 125, 67 percent complete
# assigning 0.784 to nan
#           5       6       7      8    9
# 100  0.7515   0.808  0.7925    0.8  NaN
# 125  0.7055   0.829  0.7795  0.784  NaN
# 150  0.8175  0.7825  0.8265    NaN  NaN
# 175  0.8045  0.7955   0.779    NaN  NaN
# 200   0.833   0.775   0.841    NaN  NaN
# 225  0.7495   0.831  0.8095    NaN  NaN
# Performing 8 epochs on batches of 150, 70 percent complete
# assigning 0.793 to nan
#           5       6       7      8    9
# 100  0.7515   0.808  0.7925    0.8  NaN
# 125  0.7055   0.829  0.7795  0.784  NaN
# 150  0.8175  0.7825  0.8265  0.793  NaN
# 175  0.8045  0.7955   0.779    NaN  NaN
# 200   0.833   0.775   0.841    NaN  NaN
# 225  0.7495   0.831  0.8095    NaN  NaN
# Performing 8 epochs on batches of 175, 73 percent complete
# assigning 0.84 to nan
#           5       6       7      8    9
# 100  0.7515   0.808  0.7925    0.8  NaN
# 125  0.7055   0.829  0.7795  0.784  NaN
# 150  0.8175  0.7825  0.8265  0.793  NaN
# 175  0.8045  0.7955   0.779   0.84  NaN
# 200   0.833   0.775   0.841    NaN  NaN
# 225  0.7495   0.831  0.8095    NaN  NaN
# Performing 8 epochs on batches of 200, 77 percent complete
# assigning 0.7605 to nan
#           5       6       7       8    9
# 100  0.7515   0.808  0.7925     0.8  NaN
# 125  0.7055   0.829  0.7795   0.784  NaN
# 150  0.8175  0.7825  0.8265   0.793  NaN
# 175  0.8045  0.7955   0.779    0.84  NaN
# 200   0.833   0.775   0.841  0.7605  NaN
# 225  0.7495   0.831  0.8095     NaN  NaN
# Performing 8 epochs on batches of 225, 80 percent complete
# assigning 0.846 to nan
#           5       6       7       8    9
# 100  0.7515   0.808  0.7925     0.8  NaN
# 125  0.7055   0.829  0.7795   0.784  NaN
# 150  0.8175  0.7825  0.8265   0.793  NaN
# 175  0.8045  0.7955   0.779    0.84  NaN
# 200   0.833   0.775   0.841  0.7605  NaN
# 225  0.7495   0.831  0.8095   0.846  NaN
# Performing 9 epochs on batches of 100, 83 percent complete
# assigning 0.8295 to nan
#           5       6       7       8       9
# 100  0.7515   0.808  0.7925     0.8  0.8295
# 125  0.7055   0.829  0.7795   0.784     NaN
# 150  0.8175  0.7825  0.8265   0.793     NaN
# 175  0.8045  0.7955   0.779    0.84     NaN
# 200   0.833   0.775   0.841  0.7605     NaN
# 225  0.7495   0.831  0.8095   0.846     NaN
# Performing 9 epochs on batches of 125, 87 percent complete
# assigning 0.8165 to nan
#           5       6       7       8       9
# 100  0.7515   0.808  0.7925     0.8  0.8295
# 125  0.7055   0.829  0.7795   0.784  0.8165
# 150  0.8175  0.7825  0.8265   0.793     NaN
# 175  0.8045  0.7955   0.779    0.84     NaN
# 200   0.833   0.775   0.841  0.7605     NaN
# 225  0.7495   0.831  0.8095   0.846     NaN
# Performing 9 epochs on batches of 150, 90 percent complete
# assigning 0.799 to nan
#           5       6       7       8       9
# 100  0.7515   0.808  0.7925     0.8  0.8295
# 125  0.7055   0.829  0.7795   0.784  0.8165
# 150  0.8175  0.7825  0.8265   0.793   0.799
# 175  0.8045  0.7955   0.779    0.84     NaN
# 200   0.833   0.775   0.841  0.7605     NaN
# 225  0.7495   0.831  0.8095   0.846     NaN
# Performing 9 epochs on batches of 175, 93 percent complete
# assigning 0.8435 to nan
#           5       6       7       8       9
# 100  0.7515   0.808  0.7925     0.8  0.8295
# 125  0.7055   0.829  0.7795   0.784  0.8165
# 150  0.8175  0.7825  0.8265   0.793   0.799
# 175  0.8045  0.7955   0.779    0.84  0.8435
# 200   0.833   0.775   0.841  0.7605     NaN
# 225  0.7495   0.831  0.8095   0.846     NaN
# Performing 9 epochs on batches of 200, 97 percent complete
# assigning 0.8405 to nan
#           5       6       7       8       9
# 100  0.7515   0.808  0.7925     0.8  0.8295
# 125  0.7055   0.829  0.7795   0.784  0.8165
# 150  0.8175  0.7825  0.8265   0.793   0.799
# 175  0.8045  0.7955   0.779    0.84  0.8435
# 200   0.833   0.775   0.841  0.7605  0.8405
# 225  0.7495   0.831  0.8095   0.846     NaN
# Performing 9 epochs on batches of 225, 100 percent complete
# assigning 0.7965 to nan
#           5       6       7       8       9
# 100  0.7515   0.808  0.7925     0.8  0.8295
# 125  0.7055   0.829  0.7795   0.784  0.8165
# 150  0.8175  0.7825  0.8265   0.793   0.799
# 175  0.8045  0.7955   0.779    0.84  0.8435
# 200   0.833   0.775   0.841  0.7605  0.8405
# 225  0.7495   0.831  0.8095   0.846  0.7965
# Optimal hyperparams: 8 epochs, 225 batchsize. Accuracy: 0.846
#           5       6       7       8       9
# 100  0.7515   0.808  0.7925     0.8  0.8295
# 125  0.7055   0.829  0.7795   0.784  0.8165
# 150  0.8175  0.7825  0.8265   0.793   0.799
# 175  0.8045  0.7955   0.779    0.84  0.8435
# 200   0.833   0.775   0.841  0.7605  0.8405
# 225  0.7495   0.831  0.8095   0.846  0.7965

# %%
#just reduced
gnn_grid_red = opt_hps(perform_GNN, red_feat_x.values, graph_red_feat_y, gnn_epochs, gnn_batchsizes, show_progress=True)

gnn_grid_red
