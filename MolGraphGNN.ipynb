# %%
import csv
import math
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.optimize as opt
import seaborn as sns
from scipy import stats
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.decomposition import IncrementalPCA
from tabulate import tabulate
import tensorflow as tf
import deepchem as dc
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Descriptors
from tensorflow import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
import warnings
warnings.filterwarnings('ignore')

# %%
ddi_fp = r"C:\Users\sreej\Desktop\Capstone\drugbank.tab"
ddi = pd.read_csv(ddi_fp, sep='\t')

#kaggle_fp = "Data Files\\SMILES-Kaggle\\chembl_22_clean_1576904_sorted_std_final.smi"
#smiles = pd.read_csv(kaggle_fp, sep='\t')

ddi["Y"] = ddi["Y"].astype("category")
ddi["Map"] = ddi["Map"].astype("category")

#counting interaction types for potential later weighting
interaction_counts = pd.DataFrame(ddi['Y'].value_counts().rename_axis('y').reset_index(name='count')).sort_values(by='count', ascending=False)
interaction_counts['row_num'] = interaction_counts.index + 1
interaction_counts['log_count'] = np.log(interaction_counts['count'])

#listing longer explanations of interaction types for later use
interaction_types = ddi[['Y','Map']].drop_duplicates(subset=['Y'])

#remove longer name of interaction type from main dataset
ddi = ddi.drop("Map",axis=1)

ddi.head(10)
# Out:
#        ID1      ID2  Y                                                 X1  \
# 0  DB04571  DB00460  1                CC1=CC2=CC3=C(OC(=O)C=C3C)C(C)=C2O1
# 1  DB00855  DB00460  1                                    NCC(=O)CCC(O)=O
# 2  DB09536  DB00460  1                                           O=[Ti]=O
# 3  DB01600  DB00460  1              CC(C(O)=O)C1=CC=C(S1)C(=O)C1=CC=CC=C1
# 4  DB09000  DB00460  1         CC(CN(C)C)CN1C2=CC=CC=C2SC2=C1C=C(C=C2)C#N
# 5  DB11630  DB00460  1  OC1=CC=CC(=C1)C-1=C2\CCC(=N2)\C(=C2/N\C(\C=C2)...
# 6  DB00553  DB00460  1                     COC1=C2OC(=O)C=CC2=CC2=C1OC=C2
# 7  DB06261  DB00460  1                      [H]N([H])CC(=O)CCC(=O)OCCCCCC
# 8  DB01878  DB00460  1                        O=C(C1=CC=CC=C1)C1=CC=CC=C1
# 9  DB00140  DB00460  1  CC1=C(C)C=C2N(C[C@H](O)[C@H](O)[C@H](O)CO)C3=N...
#
#                                                   X2
# 0  COC(=O)CCC1=C2NC(\C=C3/N=C(/C=C4\N\C(=C/C5=N/C...
# 1  COC(=O)CCC1=C2NC(\C=C3/N=C(/C=C4\N\C(=C/C5=N/C...
# 2  COC(=O)CCC1=C2NC(\C=C3/N=C(/C=C4\N\C(=C/C5=N/C...
# 3  COC(=O)CCC1=C2NC(\C=C3/N=C(/C=C4\N\C(=C/C5=N/C...
# 4  COC(=O)CCC1=C2NC(\C=C3/N=C(/C=C4\N\C(=C/C5=N/C...
# 5  COC(=O)CCC1=C2NC(\C=C3/N=C(/C=C4\N\C(=C/C5=N/C...
# 6  COC(=O)CCC1=C2NC(\C=C3/N=C(/C=C4\N\C(=C/C5=N/C...
# 7  COC(=O)CCC1=C2NC(\C=C3/N=C(/C=C4\N\C(=C/C5=N/C...
# 8  COC(=O)CCC1=C2NC(\C=C3/N=C(/C=C4\N\C(=C/C5=N/C...
# 9  COC(=O)CCC1=C2NC(\C=C3/N=C(/C=C4\N\C(=C/C5=N/C...

# %%
print(ddi.shape)
# Out:
# (191808, 5)

# %%
#quick function to turn a list of size 1 lists of strings into a list of strings, for later use
def delist(list_of_lists):
    list_of_strings = []
    for inner_list in list_of_lists:
        string = inner_list[0]
        list_of_strings.append(string)
    return list_of_strings

# %% [markdown]
# Preprocessing

# %%
# counting drugs by number of mentions in database
old = pd.DataFrame()
old["total"] = ddi['ID1'].value_counts()
old = old.reset_index()
old.columns = ['ID', 'count'] 
new = pd.DataFrame()
new["total"] = ddi['ID2'].value_counts()
new = new.reset_index()
new.columns = ['ID', 'count'] 
drug_counts = pd.merge(old,new,how='outer',on='ID').fillna(0)
drug_counts['total'] = drug_counts['count_x'] + drug_counts['count_y']

drug_counts = drug_counts.sort_values(by='total')
drug_counts_one = pd.DataFrame(drug_counts[drug_counts['total']==1]['ID'])

#removing drugs only in database once
ddi_proc = ddi[ ~ddi['ID1'].isin(drug_counts_one['ID'])]
ddi_proc = ddi_proc[ ~ddi_proc['ID2'].isin(drug_counts_one['ID'])]

#removing one particular drug with a problematic SMILES code
ddi_proc = ddi_proc[ddi_proc['X1']!="OC1=CC=CC(=C1)C-1=C2\CCC(=N2)\C(=C2/N\C(\C=C2)=C(/C2=N/C(/C=C2)=C(\C2=CC=C\-1N2)C1=CC(O)=CC=C1)C1=CC(O)=CC=C1)\C1=CC(O)=CC=C1"]

# %%
#create main datasets

data = dc.data.NumpyDataset(X=ddi_proc[['X1','X2']], y=ddi[['Y']])
df = data.to_dataframe()
df = df.sample(frac=1).reset_index(drop=True)

X_one = delist(df[["X1"]].values.tolist())
X_two = delist(df[["X2"]].values.tolist())

search_string = "nan"

count = X_one.count(search_string)
if count > 0:
    print(f"'{search_string}' found {count} times in X_one.")
count = X_two.count(search_string)
if count > 0:
    print(f"'{search_string}' found {count} times in X_two.")

# %%
# reduce dataset down to equal number of top 20 categories to create an equalized dataset

top20 = interaction_counts[interaction_counts['row_num'] <= 20]

reduced_df = df.merge(top20['y'], on='y')
reduced_df=reduced_df.sample(frac=1).reset_index(drop=True)

#eq_df = reduced_df.groupby('y').apply(lambda x: x.sample(min(len(x), 500))).reset_index(drop=True)

#eq_df

# %%
#print(df.columns)  
#print(top20.columns)
#print(interaction_counts)
red_df20 = reduced_df[['X1', 'X2', 'y']]
red_df20
# Out:
#                                                        X1  \
# 0       O[C@@H]1CO[C@@H](O[C@@H]2CO[C@@H](O)[C@H](OS(O...
# 1       CN1CCN(CCCN2C3=CC=CC=C3SC3=C2C=C(C=C3)C(F)(F)F...
# 2        CCN(CC)CC1=C(O)C=CC(NC2=C3C=CC(Cl)=CC3=NC=C2)=C1
# 3                                                     CCO
# 4       CN1CCN(CC1)C(=O)O[C@@H]1N(C(=O)C2=NC=CN=C12)C1...
# ...                                                   ...
# 178489  [H][C@@]12CCCN1C(=O)[C@H](CC1=CC=CC=C1)N1C(=O)...
# 178490  [H][C@@](CC)(C1=CC(NS(=O)(=O)C2=NC=C(C=C2)C(F)...
# 178491               CN1CCN2C(C1)C1=CC=CC=C1CC1=C2N=CC=C1
# 178492       CN1CCN(CCCN2C3=CC=CC=C3SC3=C2C=C(Cl)C=C3)CC1
# 178493  CCCCC1=NC(Cl)=C(CO)N1CC1=CC=C(C=C1)C1=CC=CC=C1...
#
#                                                        X2   y
# 0       C[C@@H](CC1=CC(O)=C(O)C=C1)[C@H](C)CC1=CC(O)=C...   6
# 1                  BrC1=CC2=C(NC(=O)CN=C2C2=CC=CC=N2)C=C1  49
# 2                                         NNCCC1=CC=CC=C1  73
# 3                           CC(C)NCC(O)COC1=CC=CC=C1OCC=C  16
# 4                           CCC1(CCC(=O)NC1=O)C1=CC=CC=C1  49
# ...                                                   ...  ..
# 178489  [H][C@@]12CC[C@@](O)(C#C)[C@@]1(C)CC[C@@]1([H]...  49
# 178490  COC1=CC=CC=C1OCC(O)CN1CCN(CC(=O)NC2=C(C)C=CC=C...  47
# 178491                               CC(C)OP(F)(=O)OC(C)C  73
# 178492                CC(C)NCC(O)C1=CC=C(NS(C)(=O)=O)C=C1  60
# 178493  [Mg++].C[N+](C)(C)CCO.OC1=CC=CC=C1C([O-])=O.OC...  49
#
# [178494 rows x 3 columns]

# %% [markdown]
# Information
#
# Each atom in a molecule is a node on the graph.
#
# Lines connecting nodes represent chemical bonds between atoms, with the type of bond potentially encoded as edge attributes.

# %%
import torch 
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.data import Data 
from torch_geometric.nn import GCNConv
from torch_geometric.nn import GINEConv
from torch_geometric.nn import global_mean_pool
import torch.optim as optim
from rdkit import Chem


def smiles_to_graphs1(smiles): 

    # creat RDKit Mol object
    mol = Chem.MolFromSmiles(smiles)

    if mol is None: 
        print(f'Invalid SMILES Code: {smiles}')
        return None

    # atom features
    node_features = []
    for n in mol.GetAtoms(): 
        node_features.append([n.GetAtomicNum()])
    
    # bond features 
    bond_map = {
    Chem.BondType.SINGLE: 1, 
    Chem.BondType.DOUBLE: 2, 
    Chem.BondType.TRIPLE: 3, 
    Chem.BondType.AROMATIC: 4
    } 

    bond_indices = []
    bond_type_features = []
    for b in mol.GetBonds(): 

        # bond types (bi-drectional)
        bond_type = bond_map.get(b.GetBondType(), 0)
        bond_type_features.append([bond_type])
        bond_type_features.append([bond_type])

        # bond indices (bi-drectional)
        a1_idx = b.GetBeginAtomIdx()
        a2_idx = b.GetEndAtomIdx()

        bond_indices.append([a1_idx, a2_idx])
        bond_indices.append([a2_idx, a1_idx])

    # tensors 
    node_tensor = torch.tensor(node_features, dtype = torch.float)
    bond_index_tensor = torch.tensor(bond_indices, dtype = torch.long).t().contiguous()
    bond_type_tensor = torch.tensor(bond_type_features)

    return Data(x = node_tensor, edge_index = bond_index_tensor, edge_attr = bond_type_tensor)

# %%
# helper function for process_dataset
def process_row(smiles1, smiles2): 
    mol1, mol2 = Chem.MolFromSmiles(smiles1), Chem.MolFromSmiles(smiles2)
    if not mol1 or not mol2:
        return None
    
    graph1 = smiles_to_graphs1(smiles1)
    graph2 = smiles_to_graphs1(smiles2)

    return graph1, graph2

def process_dataset(red_df20): 
    processed_data = []

    for _, row in red_df20.iterrows(): 
        smiles1, smiles2 = row['X1'], row['X2']
        result = process_row(smiles1, smiles2)
        if result: 
            graph1, graph2 = result 
            processed_data.append((graph1, graph2, row['y']))

    # list of tuples containing two Data objects for the two drug grahps, and the label
    return processed_data

# %%
class MolGraphGNN(nn.Module):
    def __init__(self, input_dim = 1, edge_dim = 1, hidden_dim = 128, out_dim = 128):
        super(MolGraphGNN, self).__init__()

        # use GINEConv due to edge_attr handling
        self.conv1 = GINEConv(nn.Linear(input_dim, hidden_dim), edge_dim = edge_dim)
        self.conv2 = GINEConv(nn.Linear(hidden_dim, hidden_dim), edge_dim = edge_dim)
        
    def forward(self, x, edge_index, edge_attr): 
        edge_attr = edge_attr.float()
        x = self.conv1(x, edge_index, edge_attr)
        x = F.relu(x)
        x = self.conv2(x, edge_index, edge_attr)
        x = F.relu(x)

        x = x.mean(dim = 0)
        return x 
    
class DDIClassifier(nn.Module): 
    def __init__(self, gnn, embedding_dim = 128, num_classes = 20):
        super(DDIClassifier, self).__init__()
        self.gnn = gnn
        self.fc1 = nn.Linear(embedding_dim * 2, 128)
        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, drug1, drug2): 
        emb1 = self.gnn(drug1.x, drug1.edge_index, drug1.edge_attr)
        emb2 = self.gnn(drug2.x, drug2.edge_index, drug2.edge_attr)

        min_batch = min(emb1.shape[0], emb2.shape[0])
        emb1, emb2 = emb1[:min_batch], emb2[:min_batch]

        if emb1.dim() == 1: 
            emb1 = emb1.unsqueeze(0)
        if emb2.dim() == 1: 
            emb2 = emb2.unsqueeze(0)
        
        print(f"emb1 shape: {emb1.shape}, emb2 shape: {emb2.shape}")
        
        x = torch.cat((emb1, emb2), dim = 1)
        print(f"Concatenated x shape: {x.shape}")

        
        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        print(f"Output x shape: {x.shape}")

        return x

# %%
processed_data = process_dataset(red_df20)
# Out:
# [21:06:40] SMILES Parse Error: syntax error while parsing: OC1=CC=CC(=C1)C-1=C2\CCC(=N2)\C(=C2/N\C(\C=C2)=C(/C2=N/C(/C=C2)=C(\C2=CC=C\-1N2)C1=CC(O)=CC=C1)C1=CC(O)=CC=C1)\C1=CC(O)=CC=C1
# [21:06:40] SMILES Parse Error: check for mistakes around position 76:
# [21:06:40] C(/C=C2)=C(\C2=CC=C\-1N2)C1=CC(O)=CC=C1)C
# [21:06:40] ~~~~~~~~~~~~~~~~~~~~^
# [21:06:40] SMILES Parse Error: Failed parsing SMILES 'OC1=CC=CC(=C1)C-1=C2\CCC(=N2)\C(=C2/N\C(\C=C2)=C(/C2=N/C(/C=C2)=C(\C2=CC=C\-1N2)C1=CC(O)=CC=C1)C1=CC(O)=CC=C1)\C1=CC(O)=CC=C1' for input: 'OC1=CC=CC(=C1)C-1=C2\CCC(=N2)\C(=C2/N\C(\C=C2)=C(/C2=N/C(/C=C2)=C(\C2=CC=C\-1N2)C1=CC(O)=CC=C1)C1=CC(O)=CC=C1)\C1=CC(O)=CC=C1'
# [21:07:42] SMILES Parse Error: syntax error while parsing: OC1=CC=CC(=C1)C-1=C2\CCC(=N2)\C(=C2/N\C(\C=C2)=C(/C2=N/C(/C=C2)=C(\C2=CC=C\-1N2)C1=CC(O)=CC=C1)C1=CC(O)=CC=C1)\C1=CC(O)=CC=C1
# [21:07:42] SMILES Parse Error: check for mistakes around position 76:
# [21:07:42] C(/C=C2)=C(\C2=CC=C\-1N2)C1=CC(O)=CC=C1)C
# [21:07:42] ~~~~~~~~~~~~~~~~~~~~^
# [21:07:42] SMILES Parse Error: Failed parsing SMILES 'OC1=CC=CC(=C1)C-1=C2\CCC(=N2)\C(=C2/N\C(\C=C2)=C(/C2=N/C(/C=C2)=C(\C2=CC=C\-1N2)C1=CC(O)=CC=C1)C1=CC(O)=CC=C1)\C1=CC(O)=CC=C1' for input: 'OC1=CC=CC(=C1)C-1=C2\CCC(=N2)\C(=C2/N\C(\C=C2)=C(/C2=N/C(/C=C2)=C(\C2=CC=C\-1N2)C1=CC(O)=CC=C1)C1=CC(O)=CC=C1)\C1=CC(O)=CC=C1'
# [21:09:20] SMILES Parse Error: syntax error while parsing: OC1=CC=CC(=C1)C-1=C2\CCC(=N2)\C(=C2/N\C(\C=C2)=C(/C2=N/C(/C=C2)=C(\C2=CC=C\-1N2)C1=CC(O)=CC=C1)C1=CC(O)=CC=C1)\C1=CC(O)=CC=C1
# [21:09:20] SMILES Parse Error: check for mistakes around position 76:
# [21:09:20] C(/C=C2)=C(\C2=CC=C\-1N2)C1=CC(O)=CC=C1)C
# [21:09:20] ~~~~~~~~~~~~~~~~~~~~^
# [21:09:20] SMILES Parse Error: Failed parsing SMILES 'OC1=CC=CC(=C1)C-1=C2\CCC(=N2)\C(=C2/N\C(\C=C2)=C(/C2=N/C(/C=C2)=C(\C2=CC=C\-1N2)C1=CC(O)=CC=C1)C1=CC(O)=CC=C1)\C1=CC(O)=CC=C1' for input: 'OC1=CC=CC(=C1)C-1=C2\CCC(=N2)\C(=C2/N\C(\C=C2)=C(/C2=N/C(/C=C2)=C(\C2=CC=C\-1N2)C1=CC(O)=CC=C1)C1=CC(O)=CC=C1)\C1=CC(O)=CC=C1'

# %%
processed_data
# Out:
# [(Data(x=[35, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   Data(x=[22, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   6),
#  (Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[19, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   49),
#  (Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[10, 1], edge_index=[2, 20], edge_attr=[20, 1]),
#   73),
#  (Data(x=[3, 1], edge_index=[2, 4], edge_attr=[4, 1]),
#   Data(x=[19, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   16),
#  (Data(x=[27, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[16, 1], edge_index=[2, 34], edge_attr=[34, 1]),
#   49),
#  (Data(x=[30, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[49, 1], edge_index=[2, 110], edge_attr=[110, 1]),
#   73),
#  (Data(x=[21, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   47),
#  (Data(x=[19, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[25, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   70),
#  (Data(x=[20, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[33, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   16),
#  (Data(x=[35, 1], edge_index=[2, 74], edge_attr=[74, 1]),
#   Data(x=[28, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   73),
#  (Data(x=[12, 1], edge_index=[2, 24], edge_attr=[24, 1]),
#   Data(x=[12, 1], edge_index=[2, 22], edge_attr=[22, 1]),
#   49),
#  (Data(x=[15, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   Data(x=[28, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   49),
#  (Data(x=[20, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   Data(x=[16, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   16),
#  (Data(x=[28, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[49, 1], edge_index=[2, 106], edge_attr=[106, 1]),
#   47),
#  (Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[27, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   16),
#  (Data(x=[28, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[33, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   47),
#  (Data(x=[63, 1], edge_index=[2, 136], edge_attr=[136, 1]),
#   Data(x=[16, 1], edge_index=[2, 34], edge_attr=[34, 1]),
#   4),
#  (Data(x=[22, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   73),
#  (Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[22, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   60),
#  (Data(x=[51, 1], edge_index=[2, 106], edge_attr=[106, 1]),
#   Data(x=[52, 1], edge_index=[2, 116], edge_attr=[116, 1]),
#   73),
#  (Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[30, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   60),
#  (Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[23, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   75),
#  (Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   73),
#  (Data(x=[23, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[22, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   49),
#  (Data(x=[26, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   Data(x=[26, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   16),
#  (Data(x=[15, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   49),
#  (Data(x=[26, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   Data(x=[52, 1], edge_index=[2, 116], edge_attr=[116, 1]),
#   73),
#  (Data(x=[30, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   Data(x=[31, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   47),
#  (Data(x=[29, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[29, 1], edge_index=[2, 64], edge_attr=[64, 1]),
#   49),
#  (Data(x=[18, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[32, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   75),
#  (Data(x=[28, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[26, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   20),
#  (Data(x=[21, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[31, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   49),
#  (Data(x=[28, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[19, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   49),
#  (Data(x=[27, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   Data(x=[37, 1], edge_index=[2, 80], edge_attr=[80, 1]),
#   49),
#  (Data(x=[24, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   37),
#  (Data(x=[37, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   Data(x=[33, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   47),
#  (Data(x=[22, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   Data(x=[21, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   49),
#  (Data(x=[34, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   Data(x=[18, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   47),
#  (Data(x=[28, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   Data(x=[15, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   49),
#  (Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[33, 1], edge_index=[2, 64], edge_attr=[64, 1]),
#   70),
#  (Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   49),
#  (Data(x=[3, 1], edge_index=[2, 4], edge_attr=[4, 1]),
#   Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   16),
#  (Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[31, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   49),
#  (Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[17, 1], edge_index=[2, 34], edge_attr=[34, 1]),
#   49),
#  (Data(x=[91, 1], edge_index=[2, 192], edge_attr=[192, 1]),
#   Data(x=[20, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   20),
#  (Data(x=[23, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[23, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   49),
#  (Data(x=[21, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[36, 1], edge_index=[2, 78], edge_attr=[78, 1]),
#   6),
#  (Data(x=[27, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   Data(x=[20, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   47),
#  (Data(x=[37, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   Data(x=[21, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   73),
#  (Data(x=[63, 1], edge_index=[2, 136], edge_attr=[136, 1]),
#   Data(x=[28, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   4),
#  (Data(x=[22, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   Data(x=[20, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   49),
#  (Data(x=[12, 1], edge_index=[2, 26], edge_attr=[26, 1]),
#   Data(x=[30, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   60),
#  (Data(x=[22, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[28, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   49),
#  (Data(x=[49, 1], edge_index=[2, 106], edge_attr=[106, 1]),
#   Data(x=[24, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   20),
#  (Data(x=[30, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   60),
#  (Data(x=[31, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   Data(x=[22, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   47),
#  (Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[28, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   47),
#  (Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[36, 1], edge_index=[2, 74], edge_attr=[74, 1]),
#   70),
#  (Data(x=[31, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   Data(x=[24, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   9),
#  (Data(x=[23, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[26, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   27),
#  (Data(x=[24, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[33, 1], edge_index=[2, 74], edge_attr=[74, 1]),
#   60),
#  (Data(x=[23, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   Data(x=[27, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   70),
#  (Data(x=[29, 1], edge_index=[2, 64], edge_attr=[64, 1]),
#   Data(x=[25, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   73),
#  (Data(x=[12, 1], edge_index=[2, 24], edge_attr=[24, 1]),
#   Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   47),
#  (Data(x=[34, 1], edge_index=[2, 74], edge_attr=[74, 1]),
#   Data(x=[34, 1], edge_index=[2, 76], edge_attr=[76, 1]),
#   73),
#  (Data(x=[26, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[19, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   47),
#  (Data(x=[19, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[23, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   49),
#  (Data(x=[29, 1], edge_index=[2, 64], edge_attr=[64, 1]),
#   Data(x=[51, 1], edge_index=[2, 114], edge_attr=[114, 1]),
#   47),
#  (Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   49),
#  (Data(x=[22, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   20),
#  (Data(x=[40, 1], edge_index=[2, 86], edge_attr=[86, 1]),
#   Data(x=[41, 1], edge_index=[2, 88], edge_attr=[88, 1]),
#   73),
#  (Data(x=[31, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   Data(x=[26, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   49),
#  (Data(x=[16, 1], edge_index=[2, 34], edge_attr=[34, 1]),
#   Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   49),
#  (Data(x=[14, 1], edge_index=[2, 30], edge_attr=[30, 1]),
#   Data(x=[12, 1], edge_index=[2, 26], edge_attr=[26, 1]),
#   49),
#  (Data(x=[22, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[71, 1], edge_index=[2, 150], edge_attr=[150, 1]),
#   20),
#  (Data(x=[32, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   Data(x=[29, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   73),
#  (Data(x=[61, 1], edge_index=[2, 132], edge_attr=[132, 1]),
#   Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   75),
#  (Data(x=[33, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   Data(x=[38, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   73),
#  (Data(x=[29, 1], edge_index=[2, 64], edge_attr=[64, 1]),
#   Data(x=[26, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   37),
#  (Data(x=[40, 1], edge_index=[2, 88], edge_attr=[88, 1]),
#   Data(x=[51, 1], edge_index=[2, 114], edge_attr=[114, 1]),
#   73),
#  (Data(x=[16, 1], edge_index=[2, 34], edge_attr=[34, 1]),
#   Data(x=[14, 1], edge_index=[2, 30], edge_attr=[30, 1]),
#   49),
#  (Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[14, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   60),
#  (Data(x=[31, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   Data(x=[32, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   47),
#  (Data(x=[22, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[29, 1], edge_index=[2, 64], edge_attr=[64, 1]),
#   75),
#  (Data(x=[15, 1], edge_index=[2, 30], edge_attr=[30, 1]),
#   Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   37),
#  (Data(x=[21, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   Data(x=[25, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   47),
#  (Data(x=[25, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   Data(x=[25, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   49),
#  (Data(x=[28, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[22, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   49),
#  (Data(x=[30, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   Data(x=[25, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   20),
#  (Data(x=[22, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[16, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   16),
#  (Data(x=[29, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[43, 1], edge_index=[2, 100], edge_attr=[100, 1]),
#   47),
#  (Data(x=[33, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   72),
#  (Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[33, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   47),
#  (Data(x=[23, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[23, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   49),
#  (Data(x=[32, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   Data(x=[24, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   47),
#  (Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[57, 1], edge_index=[2, 128], edge_attr=[128, 1]),
#   58),
#  (Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[41, 1], edge_index=[2, 88], edge_attr=[88, 1]),
#   73),
#  (Data(x=[40, 1], edge_index=[2, 88], edge_attr=[88, 1]),
#   Data(x=[52, 1], edge_index=[2, 108], edge_attr=[108, 1]),
#   73),
#  (Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[71, 1], edge_index=[2, 150], edge_attr=[150, 1]),
#   20),
#  (Data(x=[23, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[27, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   49),
#  (Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[20, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   49),
#  (Data(x=[40, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   54),
#  (Data(x=[33, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   Data(x=[32, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   49),
#  (Data(x=[13, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   Data(x=[31, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   49),
#  (Data(x=[21, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   Data(x=[33, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   73),
#  (Data(x=[22, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[19, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   49),
#  (Data(x=[62, 1], edge_index=[2, 136], edge_attr=[136, 1]),
#   Data(x=[43, 1], edge_index=[2, 100], edge_attr=[100, 1]),
#   47),
#  (Data(x=[6, 1], edge_index=[2, 12], edge_attr=[12, 1]),
#   Data(x=[35, 1], edge_index=[2, 76], edge_attr=[76, 1]),
#   47),
#  (Data(x=[31, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   Data(x=[29, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   73),
#  (Data(x=[26, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   20),
#  (Data(x=[30, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   49),
#  (Data(x=[39, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   Data(x=[25, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   20),
#  (Data(x=[31, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   Data(x=[52, 1], edge_index=[2, 108], edge_attr=[108, 1]),
#   73),
#  (Data(x=[20, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[45, 1], edge_index=[2, 98], edge_attr=[98, 1]),
#   47),
#  (Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[12, 1], edge_index=[2, 16], edge_attr=[16, 1]),
#   49),
#  (Data(x=[32, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   Data(x=[16, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   20),
#  (Data(x=[23, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[25, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   49),
#  (Data(x=[19, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[20, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   70),
#  (Data(x=[14, 1], edge_index=[2, 30], edge_attr=[30, 1]),
#   Data(x=[31, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   49),
#  (Data(x=[25, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   47),
#  (Data(x=[20, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   Data(x=[27, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   49),
#  (Data(x=[18, 1], edge_index=[2, 34], edge_attr=[34, 1]),
#   Data(x=[25, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   47),
#  (Data(x=[15, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   Data(x=[19, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   47),
#  (Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[10, 1], edge_index=[2, 18], edge_attr=[18, 1]),
#   49),
#  (Data(x=[21, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   47),
#  (Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[16, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   49),
#  (Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[32, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   49),
#  (Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[23, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   75),
#  (Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[28, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   60),
#  (Data(x=[39, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   Data(x=[21, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   49),
#  (Data(x=[36, 1], edge_index=[2, 78], edge_attr=[78, 1]),
#   Data(x=[17, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   49),
#  (Data(x=[14, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   Data(x=[14, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   49),
#  (Data(x=[3, 1], edge_index=[2, 4], edge_attr=[4, 1]),
#   Data(x=[22, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   16),
#  (Data(x=[22, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[16, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   49),
#  (Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   73),
#  (Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[20, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   70),
#  (Data(x=[14, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   47),
#  (Data(x=[36, 1], edge_index=[2, 78], edge_attr=[78, 1]),
#   Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   49),
#  (Data(x=[27, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   Data(x=[51, 1], edge_index=[2, 114], edge_attr=[114, 1]),
#   73),
#  (Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[33, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   47),
#  (Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[19, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   49),
#  (Data(x=[26, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[22, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   49),
#  (Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   49),
#  (Data(x=[37, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   Data(x=[24, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   83),
#  (Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[14, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   49),
#  (Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[30, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   75),
#  (Data(x=[23, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[17, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   16),
#  (Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   47),
#  (Data(x=[20, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[50, 1], edge_index=[2, 106], edge_attr=[106, 1]),
#   47),
#  (Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[35, 1], edge_index=[2, 76], edge_attr=[76, 1]),
#   75),
#  (Data(x=[35, 1], edge_index=[2, 74], edge_attr=[74, 1]),
#   Data(x=[32, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   73),
#  (Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[45, 1], edge_index=[2, 98], edge_attr=[98, 1]),
#   47),
#  (Data(x=[27, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   47),
#  (Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[14, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   49),
#  (Data(x=[46, 1], edge_index=[2, 100], edge_attr=[100, 1]),
#   Data(x=[73, 1], edge_index=[2, 152], edge_attr=[152, 1]),
#   73),
#  (Data(x=[43, 1], edge_index=[2, 94], edge_attr=[94, 1]),
#   Data(x=[30, 1], edge_index=[2, 64], edge_attr=[64, 1]),
#   49),
#  (Data(x=[45, 1], edge_index=[2, 98], edge_attr=[98, 1]),
#   Data(x=[52, 1], edge_index=[2, 108], edge_attr=[108, 1]),
#   70),
#  (Data(x=[60, 1], edge_index=[2, 130], edge_attr=[130, 1]),
#   Data(x=[40, 1], edge_index=[2, 86], edge_attr=[86, 1]),
#   73),
#  (Data(x=[68, 1], edge_index=[2, 142], edge_attr=[142, 1]),
#   Data(x=[45, 1], edge_index=[2, 98], edge_attr=[98, 1]),
#   73),
#  (Data(x=[34, 1], edge_index=[2, 80], edge_attr=[80, 1]),
#   Data(x=[27, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   49),
#  (Data(x=[32, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   Data(x=[65, 1], edge_index=[2, 146], edge_attr=[146, 1]),
#   75),
#  (Data(x=[11, 1], edge_index=[2, 22], edge_attr=[22, 1]),
#   Data(x=[24, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   47),
#  (Data(x=[60, 1], edge_index=[2, 130], edge_attr=[130, 1]),
#   Data(x=[30, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   49),
#  (Data(x=[25, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   60),
#  (Data(x=[19, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   49),
#  (Data(x=[37, 1], edge_index=[2, 80], edge_attr=[80, 1]),
#   Data(x=[21, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   75),
#  (Data(x=[16, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   Data(x=[28, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   4),
#  (Data(x=[3, 1], edge_index=[2, 4], edge_attr=[4, 1]),
#   Data(x=[1, 1], edge_index=[0], edge_attr=[0]),
#   16),
#  (Data(x=[30, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   73),
#  (Data(x=[22, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   47),
#  (Data(x=[33, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   Data(x=[52, 1], edge_index=[2, 108], edge_attr=[108, 1]),
#   73),
#  (Data(x=[14, 1], edge_index=[2, 26], edge_attr=[26, 1]),
#   Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   47),
#  (Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[27, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   49),
#  (Data(x=[23, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[50, 1], edge_index=[2, 106], edge_attr=[106, 1]),
#   73),
#  (Data(x=[17, 1], edge_index=[2, 34], edge_attr=[34, 1]),
#   Data(x=[21, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   73),
#  (Data(x=[26, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   Data(x=[17, 1], edge_index=[2, 34], edge_attr=[34, 1]),
#   70),
#  (Data(x=[12, 1], edge_index=[2, 24], edge_attr=[24, 1]),
#   Data(x=[31, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   67),
#  (Data(x=[25, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   20),
#  (Data(x=[39, 1], edge_index=[2, 78], edge_attr=[78, 1]),
#   Data(x=[32, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   47),
#  (Data(x=[33, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   Data(x=[85, 1], edge_index=[2, 170], edge_attr=[170, 1]),
#   47),
#  (Data(x=[58, 1], edge_index=[2, 126], edge_attr=[126, 1]),
#   Data(x=[14, 1], edge_index=[2, 30], edge_attr=[30, 1]),
#   49),
#  (Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[30, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   60),
#  (Data(x=[13, 1], edge_index=[2, 26], edge_attr=[26, 1]),
#   Data(x=[22, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   49),
#  (Data(x=[14, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   Data(x=[42, 1], edge_index=[2, 94], edge_attr=[94, 1]),
#   49),
#  (Data(x=[18, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[38, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   47),
#  (Data(x=[29, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   73),
#  (Data(x=[18, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[20, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   37),
#  (Data(x=[16, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[21, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   73),
#  (Data(x=[27, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   Data(x=[24, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   49),
#  (Data(x=[46, 1], edge_index=[2, 100], edge_attr=[100, 1]),
#   Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   73),
#  (Data(x=[31, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   Data(x=[33, 1], edge_index=[2, 74], edge_attr=[74, 1]),
#   73),
#  (Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[12, 1], edge_index=[2, 16], edge_attr=[16, 1]),
#   49),
#  (Data(x=[17, 1], edge_index=[2, 34], edge_attr=[34, 1]),
#   Data(x=[19, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   9),
#  (Data(x=[30, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   Data(x=[66, 1], edge_index=[2, 148], edge_attr=[148, 1]),
#   58),
#  (Data(x=[10, 1], edge_index=[2, 20], edge_attr=[20, 1]),
#   Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   47),
#  (Data(x=[30, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   Data(x=[57, 1], edge_index=[2, 128], edge_attr=[128, 1]),
#   70),
#  (Data(x=[25, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   Data(x=[10, 1], edge_index=[2, 20], edge_attr=[20, 1]),
#   47),
#  (Data(x=[30, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   Data(x=[30, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   47),
#  (Data(x=[10, 1], edge_index=[2, 20], edge_attr=[20, 1]),
#   Data(x=[31, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   47),
#  (Data(x=[29, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[20, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   73),
#  (Data(x=[20, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   Data(x=[20, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   16),
#  (Data(x=[28, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   Data(x=[13, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   49),
#  (Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[54, 1], edge_index=[2, 116], edge_attr=[116, 1]),
#   73),
#  (Data(x=[18, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[27, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   49),
#  (Data(x=[26, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   49),
#  (Data(x=[27, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[26, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   49),
#  (Data(x=[60, 1], edge_index=[2, 136], edge_attr=[136, 1]),
#   Data(x=[15, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   73),
#  (Data(x=[23, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[95, 1], edge_index=[2, 204], edge_attr=[204, 1]),
#   20),
#  (Data(x=[20, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   Data(x=[14, 1], edge_index=[2, 30], edge_attr=[30, 1]),
#   32),
#  (Data(x=[55, 1], edge_index=[2, 124], edge_attr=[124, 1]),
#   Data(x=[29, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   73),
#  (Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[28, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   49),
#  (Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   49),
#  (Data(x=[1, 1], edge_index=[0], edge_attr=[0]),
#   Data(x=[3, 1], edge_index=[0], edge_attr=[0]),
#   67),
#  (Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[38, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   49),
#  (Data(x=[26, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   54),
#  (Data(x=[34, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   Data(x=[21, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   9),
#  (Data(x=[30, 1], edge_index=[2, 64], edge_attr=[64, 1]),
#   Data(x=[25, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   73),
#  (Data(x=[31, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   Data(x=[14, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   49),
#  (Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[39, 1], edge_index=[2, 86], edge_attr=[86, 1]),
#   75),
#  (Data(x=[33, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   75),
#  (Data(x=[20, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[32, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   47),
#  (Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[39, 1], edge_index=[2, 88], edge_attr=[88, 1]),
#   49),
#  (Data(x=[15, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   Data(x=[9, 1], edge_index=[2, 18], edge_attr=[18, 1]),
#   47),
#  (Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[17, 1], edge_index=[2, 34], edge_attr=[34, 1]),
#   4),
#  (Data(x=[31, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   49),
#  (Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[39, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   47),
#  (Data(x=[63, 1], edge_index=[2, 136], edge_attr=[136, 1]),
#   Data(x=[29, 1], edge_index=[2, 64], edge_attr=[64, 1]),
#   75),
#  (Data(x=[23, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[32, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   47),
#  (Data(x=[13, 1], edge_index=[2, 26], edge_attr=[26, 1]),
#   Data(x=[25, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   60),
#  (Data(x=[27, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   Data(x=[23, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   49),
#  (Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[33, 1], edge_index=[2, 74], edge_attr=[74, 1]),
#   73),
#  (Data(x=[22, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   47),
#  (Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[30, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   20),
#  (Data(x=[17, 1], edge_index=[2, 34], edge_attr=[34, 1]),
#   Data(x=[21, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   49),
#  (Data(x=[40, 1], edge_index=[2, 86], edge_attr=[86, 1]),
#   Data(x=[33, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   73),
#  (Data(x=[27, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[14, 1], edge_index=[2, 30], edge_attr=[30, 1]),
#   73),
#  (Data(x=[39, 1], edge_index=[2, 88], edge_attr=[88, 1]),
#   Data(x=[43, 1], edge_index=[2, 100], edge_attr=[100, 1]),
#   47),
#  (Data(x=[12, 1], edge_index=[2, 26], edge_attr=[26, 1]),
#   Data(x=[50, 1], edge_index=[2, 106], edge_attr=[106, 1]),
#   47),
#  (Data(x=[29, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[13, 1], edge_index=[2, 24], edge_attr=[24, 1]),
#   70),
#  (Data(x=[34, 1], edge_index=[2, 76], edge_attr=[76, 1]),
#   Data(x=[54, 1], edge_index=[2, 116], edge_attr=[116, 1]),
#   73),
#  (Data(x=[28, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   Data(x=[28, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   47),
#  (Data(x=[65, 1], edge_index=[2, 148], edge_attr=[148, 1]),
#   Data(x=[77, 1], edge_index=[2, 160], edge_attr=[160, 1]),
#   73),
#  (Data(x=[7, 1], edge_index=[2, 12], edge_attr=[12, 1]),
#   Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   49),
#  (Data(x=[14, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   Data(x=[26, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   49),
#  (Data(x=[32, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   Data(x=[32, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   47),
#  (Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   49),
#  (Data(x=[89, 1], edge_index=[2, 190], edge_attr=[190, 1]),
#   Data(x=[33, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   49),
#  (Data(x=[25, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   47),
#  (Data(x=[14, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   Data(x=[22, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   47),
#  (Data(x=[29, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[49, 1], edge_index=[2, 106], edge_attr=[106, 1]),
#   47),
#  (Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[49, 1], edge_index=[2, 110], edge_attr=[110, 1]),
#   47),
#  (Data(x=[22, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[27, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   49),
#  (Data(x=[33, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   Data(x=[29, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   73),
#  (Data(x=[34, 1], edge_index=[2, 80], edge_attr=[80, 1]),
#   Data(x=[15, 1], edge_index=[2, 30], edge_attr=[30, 1]),
#   49),
#  (Data(x=[115, 1], edge_index=[2, 236], edge_attr=[236, 1]),
#   Data(x=[29, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   70),
#  (Data(x=[27, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   49),
#  (Data(x=[30, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[41, 1], edge_index=[2, 88], edge_attr=[88, 1]),
#   73),
#  (Data(x=[39, 1], edge_index=[2, 78], edge_attr=[78, 1]),
#   Data(x=[24, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   37),
#  (Data(x=[68, 1], edge_index=[2, 142], edge_attr=[142, 1]),
#   Data(x=[39, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   73),
#  (Data(x=[19, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   75),
#  (Data(x=[32, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   Data(x=[22, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   75),
#  (Data(x=[26, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   Data(x=[26, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   6),
#  (Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[37, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   49),
#  (Data(x=[16, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   Data(x=[49, 1], edge_index=[2, 106], edge_attr=[106, 1]),
#   75),
#  (Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[28, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   47),
#  (Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[22, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   70),
#  (Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[26, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   49),
#  (Data(x=[16, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   Data(x=[28, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   4),
#  (Data(x=[25, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   Data(x=[23, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   73),
#  (Data(x=[35, 1], edge_index=[2, 74], edge_attr=[74, 1]),
#   Data(x=[32, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   47),
#  (Data(x=[23, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[37, 1], edge_index=[2, 80], edge_attr=[80, 1]),
#   70),
#  (Data(x=[10, 1], edge_index=[2, 20], edge_attr=[20, 1]),
#   Data(x=[32, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   47),
#  (Data(x=[23, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[31, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   49),
#  (Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[31, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   49),
#  (Data(x=[20, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   75),
#  (Data(x=[19, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   Data(x=[36, 1], edge_index=[2, 76], edge_attr=[76, 1]),
#   49),
#  (Data(x=[23, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   73),
#  (Data(x=[15, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   Data(x=[30, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   49),
#  (Data(x=[37, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   Data(x=[37, 1], edge_index=[2, 80], edge_attr=[80, 1]),
#   73),
#  (Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[13, 1], edge_index=[2, 26], edge_attr=[26, 1]),
#   49),
#  (Data(x=[30, 1], edge_index=[2, 64], edge_attr=[64, 1]),
#   Data(x=[20, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   47),
#  (Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[27, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   49),
#  (Data(x=[6, 1], edge_index=[2, 8], edge_attr=[8, 1]),
#   Data(x=[8, 1], edge_index=[2, 12], edge_attr=[12, 1]),
#   16),
#  (Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[27, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   70),
#  (Data(x=[42, 1], edge_index=[2, 90], edge_attr=[90, 1]),
#   Data(x=[15, 1], edge_index=[2, 30], edge_attr=[30, 1]),
#   72),
#  (Data(x=[20, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[36, 1], edge_index=[2, 76], edge_attr=[76, 1]),
#   73),
#  (Data(x=[29, 1], edge_index=[2, 64], edge_attr=[64, 1]),
#   Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   70),
#  (Data(x=[17, 1], edge_index=[2, 34], edge_attr=[34, 1]),
#   Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   47),
#  (Data(x=[34, 1], edge_index=[2, 76], edge_attr=[76, 1]),
#   Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   47),
#  (Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[13, 1], edge_index=[2, 30], edge_attr=[30, 1]),
#   49),
#  (Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   9),
#  (Data(x=[23, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[17, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   70),
#  (Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[17, 1], edge_index=[2, 34], edge_attr=[34, 1]),
#   49),
#  (Data(x=[40, 1], edge_index=[2, 88], edge_attr=[88, 1]),
#   Data(x=[38, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   73),
#  (Data(x=[32, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   Data(x=[28, 1], edge_index=[2, 64], edge_attr=[64, 1]),
#   47),
#  (Data(x=[31, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   Data(x=[23, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   72),
#  (Data(x=[12, 1], edge_index=[2, 24], edge_attr=[24, 1]),
#   Data(x=[30, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   49),
#  (Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[22, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   49),
#  (Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   47),
#  (Data(x=[3, 1], edge_index=[0], edge_attr=[0]),
#   Data(x=[10, 1], edge_index=[2, 20], edge_attr=[20, 1]),
#   75),
#  (Data(x=[62, 1], edge_index=[2, 136], edge_attr=[136, 1]),
#   Data(x=[3, 1], edge_index=[2, 4], edge_attr=[4, 1]),
#   49),
#  (Data(x=[22, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[8, 1], edge_index=[2, 12], edge_attr=[12, 1]),
#   16),
#  (Data(x=[32, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   67),
#  (Data(x=[13, 1], edge_index=[2, 26], edge_attr=[26, 1]),
#   Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   49),
#  (Data(x=[35, 1], edge_index=[2, 74], edge_attr=[74, 1]),
#   Data(x=[37, 1], edge_index=[2, 80], edge_attr=[80, 1]),
#   73),
#  (Data(x=[32, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   Data(x=[23, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   49),
#  (Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[37, 1], edge_index=[2, 80], edge_attr=[80, 1]),
#   70),
#  (Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[27, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   70),
#  (Data(x=[34, 1], edge_index=[2, 74], edge_attr=[74, 1]),
#   Data(x=[20, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   49),
#  (Data(x=[30, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   Data(x=[23, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   20),
#  (Data(x=[10, 1], edge_index=[2, 18], edge_attr=[18, 1]),
#   Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   49),
#  (Data(x=[19, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[23, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   16),
#  (Data(x=[28, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[24, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   49),
#  (Data(x=[56, 1], edge_index=[2, 118], edge_attr=[118, 1]),
#   Data(x=[26, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   49),
#  (Data(x=[41, 1], edge_index=[2, 90], edge_attr=[90, 1]),
#   Data(x=[32, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   47),
#  (Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   9),
#  (Data(x=[56, 1], edge_index=[2, 118], edge_attr=[118, 1]),
#   Data(x=[31, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   49),
#  (Data(x=[24, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[51, 1], edge_index=[2, 106], edge_attr=[106, 1]),
#   47),
#  (Data(x=[22, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[20, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   70),
#  (Data(x=[19, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[27, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   70),
#  (Data(x=[15, 1], edge_index=[2, 34], edge_attr=[34, 1]),
#   Data(x=[23, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   49),
#  (Data(x=[13, 1], edge_index=[2, 24], edge_attr=[24, 1]),
#   Data(x=[45, 1], edge_index=[2, 100], edge_attr=[100, 1]),
#   49),
#  (Data(x=[21, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[24, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   49),
#  (Data(x=[39, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   Data(x=[43, 1], edge_index=[2, 100], edge_attr=[100, 1]),
#   47),
#  (Data(x=[22, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[31, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   49),
#  (Data(x=[22, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[28, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   47),
#  (Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[9, 1], edge_index=[2, 18], edge_attr=[18, 1]),
#   75),
#  (Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[25, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   49),
#  (Data(x=[31, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   Data(x=[26, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   49),
#  (Data(x=[24, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[39, 1], edge_index=[2, 86], edge_attr=[86, 1]),
#   47),
#  (Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[26, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   16),
#  (Data(x=[21, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   37),
#  (Data(x=[23, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   Data(x=[19, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   49),
#  (Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   49),
#  (Data(x=[30, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   49),
#  (Data(x=[20, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   49),
#  (Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[20, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   75),
#  (Data(x=[24, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   Data(x=[33, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   73),
#  (Data(x=[27, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[27, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   49),
#  (Data(x=[27, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[12, 1], edge_index=[2, 24], edge_attr=[24, 1]),
#   49),
#  (Data(x=[14, 1], edge_index=[2, 30], edge_attr=[30, 1]),
#   Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   60),
#  (Data(x=[50, 1], edge_index=[2, 106], edge_attr=[106, 1]),
#   Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   75),
#  (Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[22, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   47),
#  (Data(x=[28, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   49),
#  (Data(x=[27, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[20, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   73),
#  (Data(x=[32, 1], edge_index=[2, 64], edge_attr=[64, 1]),
#   Data(x=[14, 1], edge_index=[2, 30], edge_attr=[30, 1]),
#   72),
#  (Data(x=[21, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   37),
#  (Data(x=[31, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   Data(x=[23, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   20),
#  (Data(x=[23, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[10, 1], edge_index=[2, 18], edge_attr=[18, 1]),
#   49),
#  (Data(x=[14, 1], edge_index=[2, 30], edge_attr=[30, 1]),
#   Data(x=[24, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   47),
#  (Data(x=[91, 1], edge_index=[2, 190], edge_attr=[190, 1]),
#   Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   6),
#  (Data(x=[36, 1], edge_index=[2, 78], edge_attr=[78, 1]),
#   Data(x=[57, 1], edge_index=[2, 120], edge_attr=[120, 1]),
#   73),
#  (Data(x=[32, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   Data(x=[24, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   73),
#  (Data(x=[22, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[30, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   70),
#  (Data(x=[36, 1], edge_index=[2, 78], edge_attr=[78, 1]),
#   Data(x=[27, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   49),
#  (Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[23, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   49),
#  (Data(x=[21, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   Data(x=[8, 1], edge_index=[2, 12], edge_attr=[12, 1]),
#   16),
#  (Data(x=[25, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   Data(x=[34, 1], edge_index=[2, 76], edge_attr=[76, 1]),
#   73),
#  (Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[20, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   49),
#  (Data(x=[16, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   Data(x=[26, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   4),
#  (Data(x=[12, 1], edge_index=[2, 22], edge_attr=[22, 1]),
#   Data(x=[36, 1], edge_index=[2, 76], edge_attr=[76, 1]),
#   49),
#  (Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[33, 1], edge_index=[2, 74], edge_attr=[74, 1]),
#   73),
#  (Data(x=[16, 1], edge_index=[2, 30], edge_attr=[30, 1]),
#   Data(x=[32, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   47),
#  (Data(x=[23, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[29, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   20),
#  (Data(x=[13, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   Data(x=[25, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   49),
#  (Data(x=[31, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   Data(x=[28, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   67),
#  (Data(x=[16, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   Data(x=[22, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   47),
#  (Data(x=[71, 1], edge_index=[2, 150], edge_attr=[150, 1]),
#   Data(x=[23, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   70),
#  (Data(x=[34, 1], edge_index=[2, 74], edge_attr=[74, 1]),
#   Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   47),
#  (Data(x=[39, 1], edge_index=[2, 88], edge_attr=[88, 1]),
#   Data(x=[26, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   49),
#  (Data(x=[22, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   83),
#  (Data(x=[15, 1], edge_index=[2, 30], edge_attr=[30, 1]),
#   Data(x=[27, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   49),
#  (Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[19, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   73),
#  (Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[38, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   47),
#  (Data(x=[29, 1], edge_index=[2, 64], edge_attr=[64, 1]),
#   Data(x=[41, 1], edge_index=[2, 92], edge_attr=[92, 1]),
#   54),
#  (Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[22, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   49),
#  (Data(x=[22, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   49),
#  (Data(x=[39, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   Data(x=[26, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   49),
#  (Data(x=[37, 1], edge_index=[2, 80], edge_attr=[80, 1]),
#   Data(x=[23, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   75),
#  (Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[35, 1], edge_index=[2, 74], edge_attr=[74, 1]),
#   47),
#  (Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[50, 1], edge_index=[2, 106], edge_attr=[106, 1]),
#   20),
#  (Data(x=[10, 1], edge_index=[2, 22], edge_attr=[22, 1]),
#   Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   49),
#  (Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   49),
#  (Data(x=[33, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   72),
#  (Data(x=[59, 1], edge_index=[2, 126], edge_attr=[126, 1]),
#   Data(x=[22, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   4),
#  (Data(x=[39, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   Data(x=[32, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   49),
#  (Data(x=[61, 1], edge_index=[2, 132], edge_attr=[132, 1]),
#   Data(x=[33, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   4),
#  (Data(x=[16, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[20, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   73),
#  (Data(x=[40, 1], edge_index=[2, 86], edge_attr=[86, 1]),
#   Data(x=[9, 1], edge_index=[2, 16], edge_attr=[16, 1]),
#   70),
#  (Data(x=[22, 1], edge_index=[2, 48], edge_attr=[48, 1]),
# ...
#   Data(x=[20, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   70),
#  (Data(x=[23, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[32, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   75),
#  (Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[26, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   49),
#  (Data(x=[26, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   Data(x=[19, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   20),
#  (Data(x=[19, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   Data(x=[32, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   49),
#  (Data(x=[45, 1], edge_index=[2, 102], edge_attr=[102, 1]),
#   Data(x=[27, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   49),
#  (Data(x=[20, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   Data(x=[35, 1], edge_index=[2, 74], edge_attr=[74, 1]),
#   60),
#  (Data(x=[18, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   70),
#  (Data(x=[22, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[20, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   70),
#  (Data(x=[21, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   Data(x=[39, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   47),
#  (Data(x=[35, 1], edge_index=[2, 74], edge_attr=[74, 1]),
#   Data(x=[32, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   73),
#  (Data(x=[26, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[29, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   47),
#  (Data(x=[14, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   Data(x=[17, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   47),
#  (Data(x=[26, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   49),
#  (Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[26, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   47),
#  (Data(x=[19, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   49),
#  (Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[27, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   70),
#  (Data(x=[23, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[92, 1], edge_index=[2, 196], edge_attr=[196, 1]),
#   37),
#  (Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[32, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   49),
#  (Data(x=[12, 1], edge_index=[2, 22], edge_attr=[22, 1]),
#   Data(x=[20, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   49),
#  (Data(x=[31, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   Data(x=[51, 1], edge_index=[2, 106], edge_attr=[106, 1]),
#   73),
#  (Data(x=[56, 1], edge_index=[2, 118], edge_attr=[118, 1]),
#   Data(x=[39, 1], edge_index=[2, 86], edge_attr=[86, 1]),
#   49),
#  (Data(x=[15, 1], edge_index=[2, 30], edge_attr=[30, 1]),
#   Data(x=[23, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   16),
#  (Data(x=[30, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   Data(x=[39, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   47),
#  (Data(x=[27, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[32, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   49),
#  (Data(x=[26, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   Data(x=[43, 1], edge_index=[2, 100], edge_attr=[100, 1]),
#   47),
#  (Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[20, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   37),
#  (Data(x=[26, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   Data(x=[22, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   47),
#  (Data(x=[61, 1], edge_index=[2, 132], edge_attr=[132, 1]),
#   Data(x=[22, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   47),
#  (Data(x=[19, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   47),
#  (Data(x=[21, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[16, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   49),
#  (Data(x=[31, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   Data(x=[34, 1], edge_index=[2, 74], edge_attr=[74, 1]),
#   73),
#  (Data(x=[25, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   Data(x=[37, 1], edge_index=[2, 80], edge_attr=[80, 1]),
#   73),
#  (Data(x=[43, 1], edge_index=[2, 100], edge_attr=[100, 1]),
#   Data(x=[25, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   49),
#  (Data(x=[25, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[10, 1], edge_index=[2, 20], edge_attr=[20, 1]),
#   9),
#  (Data(x=[56, 1], edge_index=[2, 118], edge_attr=[118, 1]),
#   Data(x=[51, 1], edge_index=[2, 114], edge_attr=[114, 1]),
#   47),
#  (Data(x=[15, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   Data(x=[20, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   49),
#  (Data(x=[59, 1], edge_index=[2, 124], edge_attr=[124, 1]),
#   Data(x=[52, 1], edge_index=[2, 108], edge_attr=[108, 1]),
#   47),
#  (Data(x=[7, 1], edge_index=[2, 12], edge_attr=[12, 1]),
#   Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   49),
#  (Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   49),
#  (Data(x=[39, 1], edge_index=[2, 86], edge_attr=[86, 1]),
#   Data(x=[29, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   47),
#  (Data(x=[18, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[15, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   49),
#  (Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[34, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   49),
#  (Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[27, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   37),
#  (Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[18, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   54),
#  (Data(x=[16, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[26, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   49),
#  (Data(x=[23, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[51, 1], edge_index=[2, 106], edge_attr=[106, 1]),
#   47),
#  (Data(x=[14, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   Data(x=[22, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   49),
#  (Data(x=[20, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   Data(x=[8, 1], edge_index=[2, 12], edge_attr=[12, 1]),
#   16),
#  (Data(x=[30, 1], edge_index=[2, 64], edge_attr=[64, 1]),
#   Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   49),
#  (Data(x=[13, 1], edge_index=[2, 26], edge_attr=[26, 1]),
#   Data(x=[22, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   49),
#  (Data(x=[27, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   Data(x=[37, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   47),
#  (Data(x=[24, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   Data(x=[20, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   49),
#  (Data(x=[23, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   Data(x=[33, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   73),
#  (Data(x=[23, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[22, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   49),
#  (Data(x=[12, 1], edge_index=[2, 24], edge_attr=[24, 1]),
#   Data(x=[31, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   49),
#  (Data(x=[38, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   Data(x=[17, 1], edge_index=[2, 34], edge_attr=[34, 1]),
#   70),
#  (Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[19, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   27),
#  (Data(x=[32, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   73),
#  (Data(x=[65, 1], edge_index=[2, 136], edge_attr=[136, 1]),
#   Data(x=[54, 1], edge_index=[2, 116], edge_attr=[116, 1]),
#   47),
#  (Data(x=[30, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   Data(x=[11, 1], edge_index=[2, 22], edge_attr=[22, 1]),
#   37),
#  (Data(x=[4, 1], edge_index=[0], edge_attr=[0]),
#   Data(x=[36, 1], edge_index=[2, 80], edge_attr=[80, 1]),
#   75),
#  (Data(x=[45, 1], edge_index=[2, 98], edge_attr=[98, 1]),
#   Data(x=[36, 1], edge_index=[2, 78], edge_attr=[78, 1]),
#   49),
#  (Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[26, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   49),
#  (Data(x=[23, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[22, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   70),
#  (Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[43, 1], edge_index=[2, 100], edge_attr=[100, 1]),
#   49),
#  (Data(x=[32, 1], edge_index=[2, 64], edge_attr=[64, 1]),
#   Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   72),
#  (Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[18, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   49),
#  (Data(x=[27, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[10, 1], edge_index=[2, 18], edge_attr=[18, 1]),
#   20),
#  (Data(x=[18, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   Data(x=[41, 1], edge_index=[2, 92], edge_attr=[92, 1]),
#   54),
#  (Data(x=[23, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[18, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   47),
#  (Data(x=[15, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   47),
#  (Data(x=[11, 1], edge_index=[2, 22], edge_attr=[22, 1]),
#   Data(x=[37, 1], edge_index=[2, 78], edge_attr=[78, 1]),
#   47),
#  (Data(x=[1, 1], edge_index=[0], edge_attr=[0]),
#   Data(x=[7, 1], edge_index=[2, 12], edge_attr=[12, 1]),
#   49),
#  (Data(x=[29, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[26, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   73),
#  (Data(x=[20, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   Data(x=[19, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   49),
#  (Data(x=[29, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   Data(x=[27, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   49),
#  (Data(x=[39, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   Data(x=[37, 1], edge_index=[2, 80], edge_attr=[80, 1]),
#   70),
#  (Data(x=[19, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   4),
#  (Data(x=[25, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[31, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   60),
#  (Data(x=[62, 1], edge_index=[2, 136], edge_attr=[136, 1]),
#   Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   49),
#  (Data(x=[21, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[15, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   49),
#  (Data(x=[62, 1], edge_index=[2, 136], edge_attr=[136, 1]),
#   Data(x=[28, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   49),
#  (Data(x=[38, 1], edge_index=[2, 80], edge_attr=[80, 1]),
#   Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   72),
#  (Data(x=[30, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[17, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   47),
#  (Data(x=[25, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[12, 1], edge_index=[2, 24], edge_attr=[24, 1]),
#   49),
#  (Data(x=[34, 1], edge_index=[2, 74], edge_attr=[74, 1]),
#   Data(x=[19, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   49),
#  (Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[27, 1], edge_index=[2, 60], edge_attr=[60, 1]),
#   6),
#  (Data(x=[27, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[26, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   37),
#  (Data(x=[35, 1], edge_index=[2, 78], edge_attr=[78, 1]),
#   Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   49),
#  (Data(x=[39, 1], edge_index=[2, 84], edge_attr=[84, 1]),
#   Data(x=[19, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   73),
#  (Data(x=[22, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[51, 1], edge_index=[2, 106], edge_attr=[106, 1]),
#   73),
#  (Data(x=[65, 1], edge_index=[2, 134], edge_attr=[134, 1]),
#   Data(x=[22, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   49),
#  (Data(x=[30, 1], edge_index=[2, 64], edge_attr=[64, 1]),
#   Data(x=[35, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   49),
#  (Data(x=[27, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   Data(x=[19, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   49),
#  (Data(x=[33, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   Data(x=[25, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   49),
#  (Data(x=[26, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[35, 1], edge_index=[2, 72], edge_attr=[72, 1]),
#   70),
#  (Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   Data(x=[9, 1], edge_index=[2, 18], edge_attr=[18, 1]),
#   75),
#  (Data(x=[46, 1], edge_index=[2, 100], edge_attr=[100, 1]),
#   Data(x=[30, 1], edge_index=[2, 66], edge_attr=[66, 1]),
#   73),
#  (Data(x=[63, 1], edge_index=[2, 136], edge_attr=[136, 1]),
#   Data(x=[28, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   4),
#  (Data(x=[32, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   Data(x=[20, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   83),
#  (Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   Data(x=[22, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   49),
#  (Data(x=[82, 1], edge_index=[2, 176], edge_attr=[176, 1]),
#   Data(x=[27, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   49),
#  (Data(x=[33, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   Data(x=[43, 1], edge_index=[2, 100], edge_attr=[100, 1]),
#   47),
#  (Data(x=[21, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   49),
#  (Data(x=[36, 1], edge_index=[2, 80], edge_attr=[80, 1]),
#   Data(x=[52, 1], edge_index=[2, 108], edge_attr=[108, 1]),
#   73),
#  (Data(x=[23, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   49),
#  (Data(x=[61, 1], edge_index=[2, 132], edge_attr=[132, 1]),
#   Data(x=[33, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   4),
#  (Data(x=[27, 1], edge_index=[2, 56], edge_attr=[56, 1]),
#   Data(x=[45, 1], edge_index=[2, 98], edge_attr=[98, 1]),
#   60),
#  (Data(x=[33, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   Data(x=[21, 1], edge_index=[2, 44], edge_attr=[44, 1]),
#   9),
#  (Data(x=[22, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[18, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   16),
#  (Data(x=[16, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   Data(x=[16, 1], edge_index=[2, 32], edge_attr=[32, 1]),
#   60),
#  (Data(x=[65, 1], edge_index=[2, 134], edge_attr=[134, 1]),
#   Data(x=[3, 1], edge_index=[2, 4], edge_attr=[4, 1]),
#   49),
#  (Data(x=[44, 1], edge_index=[2, 98], edge_attr=[98, 1]),
#   Data(x=[19, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   49),
#  (Data(x=[13, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   Data(x=[28, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   49),
#  (Data(x=[65, 1], edge_index=[2, 136], edge_attr=[136, 1]),
#   Data(x=[28, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   47),
#  (Data(x=[24, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   49),
#  (Data(x=[54, 1], edge_index=[2, 122], edge_attr=[122, 1]),
#   Data(x=[32, 1], edge_index=[2, 70], edge_attr=[70, 1]),
#   47),
#  (Data(x=[22, 1], edge_index=[2, 48], edge_attr=[48, 1]),
#   Data(x=[28, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   49),
#  (Data(x=[21, 1], edge_index=[2, 40], edge_attr=[40, 1]),
#   Data(x=[23, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   6),
#  (Data(x=[32, 1], edge_index=[2, 68], edge_attr=[68, 1]),
#   Data(x=[76, 1], edge_index=[2, 166], edge_attr=[166, 1]),
#   75),
#  (Data(x=[23, 1], edge_index=[2, 52], edge_attr=[52, 1]),
#   Data(x=[7, 1], edge_index=[2, 12], edge_attr=[12, 1]),
#   49),
#  (Data(x=[61, 1], edge_index=[2, 132], edge_attr=[132, 1]),
#   Data(x=[33, 1], edge_index=[2, 74], edge_attr=[74, 1]),
#   73),
#  (Data(x=[14, 1], edge_index=[2, 30], edge_attr=[30, 1]),
#   Data(x=[24, 1], edge_index=[2, 54], edge_attr=[54, 1]),
#   49),
#  (Data(x=[14, 1], edge_index=[2, 28], edge_attr=[28, 1]),
#   Data(x=[29, 1], edge_index=[2, 62], edge_attr=[62, 1]),
#   49),
#  (Data(x=[61, 1], edge_index=[2, 132], edge_attr=[132, 1]),
#   Data(x=[21, 1], edge_index=[2, 46], edge_attr=[46, 1]),
#   4),
#  (Data(x=[19, 1], edge_index=[2, 42], edge_attr=[42, 1]),
#   Data(x=[27, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   70),
#  (Data(x=[37, 1], edge_index=[2, 82], edge_attr=[82, 1]),
#   Data(x=[19, 1], edge_index=[2, 36], edge_attr=[36, 1]),
#   49),
#  (Data(x=[18, 1], edge_index=[2, 38], edge_attr=[38, 1]),
#   Data(x=[23, 1], edge_index=[2, 50], edge_attr=[50, 1]),
#   49),
#  (Data(x=[27, 1], edge_index=[2, 58], edge_attr=[58, 1]),
#   Data(x=[30, 1], edge_index=[2, 64], edge_attr=[64, 1]),
#   49),
#  ...]

# %%
from torch_geometric.loader import DataLoader
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(processed_data, test_size = 0.2, random_state = 42, stratify = [label for _, _, label in processed_data])


train_loader = DataLoader(train_data, batch_size = 32, shuffle = True)
test_loader = DataLoader(test_data, batch_size = 32, shuffle = False)

print(f"drug1 batch size: {drug1.x.shape[0]}, drug2 batch size: {drug2.x.shape[0]}")
print(f"Labels batch size: {labels.shape[0]}")
# Out:
# drug1 batch size: 727, drug2 batch size: 862
# Labels batch size: 32

# %%
import torch 
import torch.optim as opti
import torch.nn as nn

gnn_model = MolGraphGNN(input_dim = 1, edge_dim = 1, hidden_dim = 128, out_dim = 128)

ddi_classifier = DDIClassifier(gnn=gnn_model, embedding_dim = 128, num_classes= 20)
optimizer = optim.Adam(ddi_classifier.parameters(), lr = 0.01)

criterion = nn.CrossEntropyLoss()
device = torch.device('cpu')
ddi_classifier.to(device)
# Out:
# DDIClassifier(
#   (gnn): MolGraphGNN(
#     (conv1): GINEConv(nn=Linear(in_features=1, out_features=128, bias=True))
#     (conv2): GINEConv(nn=Linear(in_features=128, out_features=128, bias=True))
#   )
#   (fc1): Linear(in_features=256, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=20, bias=True)
# )

# %%
# Training Loop
epochs = 10
for epoch in range(epochs):
    gnn_model.train()  # Set the model to training mode
    running_loss = 0.0
    
    # Iterate through the training batches
    for batch_idx, (drug1, drug2, labels) in enumerate(train_loader):
        # Forward pass
        optimizer.zero_grad()
        outputs = gnn_model(drug1, drug2)
        
        # Compute loss
        loss = criterion(outputs, labels.long())  # Ensure labels are long type
        loss.backward()  # Backpropagation
        
        # Update model weights
        optimizer.step()

        running_loss += loss.item()

    # Log training loss every epoch
    avg_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}")

    # Validation after every epoch (optional)
    gnn_model.eval()  # Set the model to evaluation mode
    with torch.no_grad():
        val_loss = 0.0
        correct = 0
        total = 0
        for drug1, drug2, labels in test_loader:
            outputs = gnn_model(drug1, drug2)
            loss = criterion(outputs, labels.long())
            val_loss += loss.item()

            # Calculate accuracy (if needed)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        avg_val_loss = val_loss / len(test_loader)
        accuracy = 100 * correct / total
        print(f"Validation Loss: {avg_val_loss:.4f}, Accuracy: {accuracy:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 11
#       8 for batch_idx, (drug1, drug2, labels) in enumerate(train_loader):
#       9     # Forward pass
#      10     optimizer.zero_grad()
# ---> 11     outputs = gnn_model(drug1, drug2)
#      13     # Compute loss
#      14     loss = criterion(outputs, labels.long())  # Ensure labels are long type
#
# File c:\Users\sreej\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\sreej\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# TypeError: MolGraphGNN.forward() missing 1 required positional argument: 'edge_attr'

# %%
num_epochs = 10
for epoch in range(num_epochs):
    ddi_classifier.train()
    total_loss = 0 
    correct = 0 
    total = 0

    for batch in train_loader: 
        drug1, drug2, labels = batch
        drug1 = drug1.to(device)
        drug2 = drug2.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = ddi_classifier(drug1, drug2)

        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        _, pred = torch.max(outputs, dim = 1)
        correct += pred.eq(labels).sum().item()
        total += labels.size(0)

    epoch_loss = total_loss/len(train_loader) 
    epoch_acc = correct/total
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.4f}')

    # evaluation phase 
    ddi_classifier.eval()
    test_loss = 0 
    correct = 0 
    total = 0 

    with torch.no_grad(): 
        for batch in test_loader: 
            drug1, drug2, labels = batch
            drug1 = drug1.to(device)
            drug2 = drug2.to(device)
            labels = labels.to(device)

# %%
# Initialize the model, optimizer, and criterion


gnn_model = MolGraphGNN(input_dim=1, edge_dim=1, hidden_dim=128, out_dim=128)
ddi_classifier = DDIClassifier(gnn=gnn_model, embedding_dim=128, num_classes=20)  # Adjust num_classes if needed
optimizer = torch.optim.Adam(ddi_classifier.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()  # For binary classification

device = torch.device('cpu')
ddi_classifier.to(device)

num_epochs = 10
for epoch in range(num_epochs): 
    ddi_classifier.train()
    total_loss = 0 
    correct = 0 
    total = 0

    for batch in train_loader: 
        drug1, drug2, labels = batch
        drug1 = drug1.to(device)
        drug2 = drug2.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = ddi_classifier(drug1, drug2)

        print(f"Outputs shape: {outputs.shape}, Labels shape: {labels.shape}")
        loss = criterion(outputs, labels.long())
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        _, pred = torch.max(outputs, dim=1)
        correct += pred.eq(labels).sum().item()
        total += labels.size(0)

    epoch_loss = total_loss / len(train_loader)
    epoch_acc = correct/total
    print(f'Accuracy: {epoch_acc}')

ddi_classifier.eval()
test_loss = 0
correct = 0
total = 0

with torch.no_grad():
    for batch in test_loader:
        drug1, drug2, labels = batch
        drug1 = drug1.to(device)
        drug2 = drug2.to(device)
        labels = labels.to(device)
        
        # Forward pass
        outputs = ddi_classifier(drug1, drug2)
        print(f"Outputs shape: {outputs.shape}, Labels shape: {labels.shape}")
        
        # Compute loss
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        
        # Compute accuracy
        _, pred = torch.max(outputs, dim=1)
        correct += pred.eq(labels).sum().item()
        total += labels.size(0)

test_loss /= len(test_loader)
test_acc = correct / total
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}")
# Out:
# emb1 shape: torch.Size([1, 128]), emb2 shape: torch.Size([1, 128])
# Concatenated x shape: torch.Size([1, 256])
# Output x shape: torch.Size([1, 20])
# Outputs shape: torch.Size([1, 20]), Labels shape: torch.Size([32])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 30
#      27 outputs = ddi_classifier(drug1, drug2)
#      29 print(f"Outputs shape: {outputs.shape}, Labels shape: {labels.shape}")
# ---> 30 loss = criterion(outputs, labels.long())
#      31 loss.backward()
#      32 optimizer.step()
#
# File c:\Users\sreej\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\sreej\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\sreej\anaconda3\Lib\site-packages\torch\nn\modules\loss.py:1295, in CrossEntropyLoss.forward(self, input, target)
#    1294 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# -> 1295     return F.cross_entropy(
#    1296         input,
#    1297         target,
#    1298         weight=self.weight,
#    1299         ignore_index=self.ignore_index,
#    1300         reduction=self.reduction,
#    1301         label_smoothing=self.label_smoothing,
#    1302     )
#
# File c:\Users\sreej\anaconda3\Lib\site-packages\torch\nn\functional.py:3494, in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    3492 if size_average is not None or reduce is not None:
#    3493     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3494 return torch._C._nn.cross_entropy_loss(
#    3495     input,
#    3496     target,
#    3497     weight,
#    3498     _Reduction.get_enum(reduction),
#    3499     ignore_index,
#    3500     label_smoothing,
#    3501 )
#
# ValueError: Expected input batch_size (1) to match target batch_size (32).
